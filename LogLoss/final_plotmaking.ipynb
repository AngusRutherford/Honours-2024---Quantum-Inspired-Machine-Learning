# %%
using DelimitedFiles
using Plots
using Plots.Measures

# alpha = pm 4, seeds are 700-719 and 1600-1619, same dataset RNG, this is MPS initialisation seed - smallest is OBC, largest is PBC
# test_accs_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_correlation_alphapm04_eta03_test_OBC_seed_1600-1619.csv", ',')
# test_accs_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_correlation_alphapm04_eta03_test_PBC_seed_1600-1619.csv", ',')
# test_accs_OBC_2 = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/angus_correlation_alphapm04_eta03_test_OBC_seed_700-719.csv", ',')
# test_accs_PBC_2 = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/angus_correlation_alphapm04_eta03_test_PBC_seed_700-719.csv", ',')

# alpha = 4, seeds are 700-719 and 1600-1619, same dataset RNG, this is MPS initialisation seed - smallest is PBC, largest is PBC
# test_accs_OBC_1 = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/angus_correlation_alpha04_eta03_test_OBC_seed_1600-1619.csv", ',')
# test_accs_PBC_1 = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/angus_correlation_alpha04_eta03_test_PBC_seed_1600-1619.csv", ',')
# test_accs_OBC_2 = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/angus_correlation_alpha04_eta03_test_OBC_seed_700-719.csv", ',')
# test_accs_PBC_2 = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/angus_correlation_alpha04_eta03_test_PBC_seed_700-719.csv", ',')

# train_accs_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/train_OBC_stoud_vary_beta_corr_alpha08_chi3_eta02.csv", ',')
# test_accs_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/test_OBC_stoud_vary_beta_corr_alpha08_chi3_eta02.csv", ',')
# train_accs_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/train_PBC_stoud_vary_beta_corr_alpha08_chi3_eta02.csv", ',')
# test_accs_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/test_PBC_stoud_vary_beta_corr_alpha08_chi3_eta02.csv", ',')

test_accs_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/angus_correlation_alpha08_eta03_test_OBC_seed_1600-1619.csv", ',')
test_accs_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/angus_correlation_alpha08_eta03_test_PBC_seed_1600-1619.csv", ',')

# test_accs_OBC = (test_accs_OBC_1 + test_accs_OBC_2) / 2
# test_accs_PBC = (test_accs_PBC_1 + test_accs_PBC_2) / 2

corr_locs = 2:20
betas = 0.1:0.1:2

# Create the heatmap
p = heatmap(
    corr_locs, betas, test_accs_PBC,
    c = :viridis,  # Color scale
    title = "Test Accuracy Heatmap, PBC \n \$\\alpha_{A},\\alpha_{B}=0.4\$, \$\\beta_{A}=-\\beta_{B}\$, \$\\chi_{max}=3\$ \n Averaged Across 40 Seeds",  # Title with two lines
    xlabel = "Correlation Locations",
    ylabel = "\$|\\beta|\$",
    size = (1600, 1300),  # Adjust the size of the plot
    clims = (minimum(test_accs_OBC), maximum(test_accs_PBC)),  # Set color limits from OBC and PBC data
    colorbar_title = " \nAccuracy",
    colorbar_titlefontsize = 40,
    titlefontsize = 40,
    xlabelfontsize = 40,
    ylabelfontsize = 40,
    #guidefontsize = 16,  # Font size for axis titles
    tickfontsize = 30,  # Font size for axis ticks
    right_margin = 34mm,  # Adjust right margin to fit the colorbar
    left_margin = 7mm,
    top_margin = 16mm,
    bottom_margin = 5mm
)

#savefig(p, "test_PBC_stoud_vary_beta_corr_alpha04_chi3_eta03_seeds40_heatmap.pdf")

# %%
using Plots
using LaTeXStrings
using DelimitedFiles
pgfplotsx()  # Switch to PGFPlotsX backend for LaTeX-style plots

# Load test accuracies
test_accs_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/angus_correlation_alpha08_eta03_test_OBC_seed_1600-1619.csv", ',')
test_accs_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/angus_correlation_alpha08_eta03_test_PBC_seed_1600-1619.csv", ',')

corr_locs = 2:20
betas = 0.1:0.1:2

#Create OBC heatmap
p1 = heatmap(
    corr_locs, betas, test_accs_OBC,
    color=cgrad([:white, :red]),
    xlabel="Correlation Locations",
    ylabel=L"|{\beta}|",  # Corrected LaTeX for β
    size=(800, 800),
    clims=(minimum(test_accs_OBC), maximum(test_accs_PBC)),
    xlabelfontsize = 40,   
    ylabelfontsize = 40,
    colorbar_titlefontsize = 40,
    colorbar_tickfontsize = 40, 
    tickfontsize = 40
)

# # # Create PBC heatmap
p2 = heatmap(
    corr_locs, betas, test_accs_PBC,
    color=cgrad([:white, :red]),
    xlabel="Correlation Locations",
    ylabel=L"|{\beta}|",
    size=(800, 800),
    clims=(minimum(test_accs_OBC), maximum(test_accs_PBC)),
    colorbar_title=" \nAccuracy",
    xlabelfontsize = 40,
    ylabelfontsize = 40,
    colorbar_titlefontsize = 40,
    colorbar_tickfontsize = 40,
    tickfontsize = 40
)

# # Combine the two heatmaps into a 1x2 layout
plot(p1, p2, layout=(1, 2), size=(1600, 800))
savefig("new_test.svg")

# Save as a .tex file
# savefig("combined_test_accs_heatmap.tex")
# Out:
# "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/new_test.svg"

# %%
using DelimitedFiles
using Plots
using Plots.Measures
using Statistics

test_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_correlation_betapm2_alpha08_eta03_test_OBC_seed_1600-1619.csv", ',')
test_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_correlation_betapm2_alpha08_eta03_test_PBC_seed_1600-1619.csv", ',')

# test_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_correlation_betapm2_alphapm04_eta03_test_OBC_seed_1600-1619.csv", ',')
# test_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_correlation_betapm2_alphapm04_eta03_test_PBC_seed_1600-1619.csv", ',')

mean_OBC = mean(test_OBC, dims = 2)
std_OBC = std(test_OBC, dims = 2)

mean_PBC = mean(test_PBC, dims = 2)
std_PBC = std(test_PBC, dims = 2)

corr_locs = 2:20
plot(corr_locs, mean_OBC, ribbon = std_OBC, label = "OBC", markersize = 7, mc = :blue, lw = 4)
plot!(corr_locs, mean_PBC, ribbon = std_PBC, label = "PBC", markersize = 7, mc = :red, lw = 4)

xlabel!("Correlation Location", fontsize = 20)
ylabel!("Accuracy", fontsize = 20)
title!("Comparison of OBC and PBC MPS Classification \n Algorithms for \$\\alpha_{A},\\alpha_{B}=0.8\$, \$\\beta_{A},\\beta_{B}=\\pm2\$, \$\\chi_{max}=3\$")
plot!(
    xguidefont=font(25),
    yguidefont=font(25),
    xtickfont=font(16),
    ytickfont=font(16),
    legendfontsize = 16,
    size = (1200, 800),
    legend=:best,
    titlefontsize = 30,
    left_margin = 5mm,
    bottom_margin = 5mm,
    top_margin = 10mm,
    right_margin = 5mm
)

savefig("OBC_vs_PBC_alpha08_betapm2.png")
# Out:
# "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/OBC_vs_PBC_alpha08_betapm2.png"

# %%
using Statistics
using StatsPlots
using DataFrames
OBC_1_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_1_4_leg_chi16_eta02_sweeps20_test_OBC.csv")
PBC_left_1_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_1_4_leg_chi16_eta02_sweeps20_test_PBC_left.csv")
PBC_right_1_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_1_4_leg_chi16_eta02_sweeps20_test_PBC_right.csv")
PBC_both_1_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_1_4_leg_chi16_eta02_sweeps20_test_PBC_both.csv")
PBC_random_1_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_1_4_leg_chi16_eta02_sweeps20_test_PBC_random.csv")

OBC_2_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_2_4_leg_chi16_eta02_sweeps20_test_OBC.csv")
PBC_left_2_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_2_4_leg_chi16_eta02_sweeps20_test_PBC_left.csv")
PBC_right_2_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_2_4_leg_chi16_eta02_sweeps20_test_PBC_right.csv")
PBC_both_2_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_2_4_leg_chi16_eta02_sweeps20_test_PBC_both.csv")
PBC_random_2_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_2_4_leg_chi16_eta02_sweeps20_test_PBC_random.csv")

OBC_3_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_3_4_leg_chi16_eta02_sweeps20_test_OBC.csv")
PBC_left_3_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_3_4_leg_chi16_eta02_sweeps20_test_PBC_left.csv")
PBC_right_3_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_3_4_leg_chi16_eta02_sweeps20_test_PBC_right.csv")
PBC_both_3_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_3_4_leg_chi16_eta02_sweeps20_test_PBC_both.csv")
PBC_random_3_4_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_3_4_leg_chi16_eta02_sweeps20_test_PBC_random.csv")

OBC_1_4_test = [parse.(Float64, split(row, ",")) for row in OBC_1_4_test]
OBC_1_4_test = reduce(hcat, OBC_1_4_test)'
OBC_1_4_test = copy(OBC_1_4_test)

PBC_left_1_4_test = [parse.(Float64, split(row, ",")) for row in PBC_left_1_4_test]
PBC_left_1_4_test = reduce(hcat, PBC_left_1_4_test)'
PBC_left_1_4_test = copy(PBC_left_1_4_test)

PBC_right_1_4_test = [parse.(Float64, split(row, ",")) for row in PBC_right_1_4_test]
PBC_right_1_4_test = reduce(hcat, PBC_right_1_4_test)'
PBC_right_1_4_test = copy(PBC_right_1_4_test)

PBC_both_1_4_test = [parse.(Float64, split(row, ",")) for row in PBC_both_1_4_test]
PBC_both_1_4_test = reduce(hcat, PBC_both_1_4_test)'
PBC_both_1_4_test = copy(PBC_both_1_4_test)

PBC_random_1_4_test = [parse.(Float64, split(row, ",")) for row in PBC_random_1_4_test]
PBC_random_1_4_test = reduce(hcat, PBC_random_1_4_test)'
PBC_random_1_4_test = copy(PBC_random_1_4_test)

OBC_2_4_test = [parse.(Float64, split(row, ",")) for row in OBC_2_4_test]
OBC_2_4_test = reduce(hcat, OBC_2_4_test)'
OBC_2_4_test = copy(OBC_2_4_test)

PBC_left_2_4_test = [parse.(Float64, split(row, ",")) for row in PBC_left_2_4_test]
PBC_left_2_4_test = reduce(hcat, PBC_left_2_4_test)'
PBC_left_2_4_test = copy(PBC_left_2_4_test)

PBC_right_2_4_test = [parse.(Float64, split(row, ",")) for row in PBC_right_2_4_test]
PBC_right_2_4_test = reduce(hcat, PBC_right_2_4_test)'
PBC_right_2_4_test = copy(PBC_right_2_4_test)

PBC_both_2_4_test = [parse.(Float64, split(row, ",")) for row in PBC_both_2_4_test]
PBC_both_2_4_test = reduce(hcat, PBC_both_2_4_test)'
PBC_both_2_4_test = copy(PBC_both_2_4_test)

PBC_random_2_4_test = [parse.(Float64, split(row, ",")) for row in PBC_random_2_4_test]
PBC_random_2_4_test = reduce(hcat, PBC_random_2_4_test)'
PBC_random_2_4_test = copy(PBC_random_2_4_test)

OBC_3_4_test = [parse.(Float64, split(row, ",")) for row in OBC_3_4_test]
OBC_3_4_test = reduce(hcat, OBC_3_4_test)'
OBC_3_4_test = copy(OBC_3_4_test)

PBC_left_3_4_test = [parse.(Float64, split(row, ",")) for row in PBC_left_3_4_test]
PBC_left_3_4_test = reduce(hcat, PBC_left_3_4_test)'
PBC_left_3_4_test = copy(PBC_left_3_4_test)

PBC_right_3_4_test = [parse.(Float64, split(row, ",")) for row in PBC_right_3_4_test]
PBC_right_3_4_test = reduce(hcat, PBC_right_3_4_test)'
PBC_right_3_4_test = copy(PBC_right_3_4_test)

PBC_both_3_4_test = [parse.(Float64, split(row, ",")) for row in PBC_both_3_4_test]
PBC_both_3_4_test = reduce(hcat, PBC_both_3_4_test)'
PBC_both_3_4_test = copy(PBC_both_3_4_test)

PBC_random_3_4_test = [parse.(Float64, split(row, ",")) for row in PBC_random_3_4_test]
PBC_random_3_4_test = reduce(hcat, PBC_random_3_4_test)'
PBC_random_3_4_test = copy(PBC_random_3_4_test)

OBC_1_4_mean = mean(OBC_1_4_test, dims = 1)
PBC_left_1_4_mean = mean(PBC_left_1_4_test, dims = 1)
PBC_right_1_4_mean = mean(PBC_right_1_4_test, dims = 1)
PBC_both_1_4_mean = mean(PBC_both_1_4_test, dims = 1)
PBC_random_1_4_mean = mean(PBC_random_1_4_test, dims = 1)

OBC_2_4_mean = mean(OBC_2_4_test, dims = 1)
PBC_left_2_4_mean = mean(PBC_left_2_4_test, dims = 1)
PBC_right_2_4_mean = mean(PBC_right_2_4_test, dims = 1)
PBC_both_2_4_mean = mean(PBC_both_2_4_test, dims = 1)
PBC_random_2_4_mean = mean(PBC_random_2_4_test, dims = 1)

OBC_3_4_mean = mean(OBC_3_4_test, dims = 1)
PBC_left_3_4_mean = mean(PBC_left_3_4_test, dims = 1)
PBC_right_3_4_mean = mean(PBC_right_3_4_test, dims = 1)
PBC_both_3_4_mean = mean(PBC_both_3_4_test, dims = 1)
PBC_random_3_4_mean = mean(PBC_random_3_4_test, dims = 1)

means_1_4 = [maximum(OBC_1_4_mean), maximum(PBC_right_1_4_mean), maximum(PBC_left_1_4_mean), maximum(PBC_both_1_4_mean), maximum(PBC_random_1_4_mean)]
means_2_4 = [maximum(OBC_2_4_mean), maximum(PBC_right_2_4_mean), maximum(PBC_left_2_4_mean), maximum(PBC_both_2_4_mean), maximum(PBC_random_2_4_mean)]
means_3_4 = [maximum(OBC_3_4_mean), maximum(PBC_right_3_4_mean), maximum(PBC_left_3_4_mean), maximum(PBC_both_3_4_mean), maximum(PBC_random_3_4_mean)]

algorithms = ["OBC", "PBC_right", "PBC_left", "PBC_both", "PBC_random"]
data_lengths = ["1/4", "2/4", "3/4"]


# Organize the mean accuracies into a matrix
#means = hcat(means_1_4, means_2_4, means_3_4)'  # Transpose to get a 3x5 matrix


# Prepare data in long format
df = DataFrame(
    DataLength = repeat(data_lengths, inner = length(algorithms)),
    Algorithm = repeat(algorithms, outer = length(data_lengths)),
    MeanAccuracy = vcat(means_1_4, means_2_4, means_3_4)
)

# Create the grouped bar chart using DataFrame syntax
@df df groupedbar(
    :DataLength,
    :MeanAccuracy,
    group = :Algorithm,
    xlabel = "Data Length",
    ylabel = "Mean Accuracy",
    title = "Algorithm Performance by Data Length",
    legend = :top,
    size = (800, 600)
)

# Display the plot
display(current())

@show means_1_4
@show means_2_4
@show means_3_4
# Out:
# means_1_4 = [0.48, 0.4061184210526315, 0.5198684210526314, 0.5497368421052631, 0.4980263157894737]
# means_2_4 = [0.48717105263157895, 0.43717105263157896, 0.5511842105263158, 0.582236842105263, 0.5496052631578947]
# means_3_4 = [0.47730263157894737, 0.40394736842105267, 0.555, 0.5722368421052633, 0.5201315789473684]
# 5-element Vector{Float64}:
#  0.47730263157894737
#  0.40394736842105267
#  0.555
#  0.5722368421052633
#  0.5201315789473684

# %%
include("RealRealHighDimension.jl")
using DelimitedFiles
using Plots
using Plots.Measures

(X_train, y_train), (X_test, y_test) = load_splits_txt("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/SwedishLeaf_TRAIN.txt", 
"/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/SwedishLeaf_TEST.txt", "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/SwedishLeaf_TEST.txt")

indices = findall(x -> x == 10, y_train)
x = range(0, stop = 2pi, length = length(X_train[1, :]))
x_tick_vals = range(0, stop = 2pi, length = 5)
x_tick_labels = ["0", "π/2", "π", "3π/2", "2π"]
plot(x, X_train[23, :], xticks = (x_tick_vals, x_tick_labels), lw = 4,
legend = false, grid = false, yaxis = false, xtickfontsize=20)
savefig("swedish_class_ten.svg")
# Out:
# "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/swedish_class_ten.svg"

# %%
include("RealRealHighDimension.jl")
using DelimitedFiles
using Plots
using Plots.Measures

(X_train, y_train), (X_test, y_test) = load_splits_txt("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/ArrowHead_TRAIN.txt", 
"/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/ArrowHead_TEST.txt", "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/ArrowHead_TEST.txt")

indices = findall(x -> x == 2, y_train)
x = range(0, stop = 2pi, length = length(X_train[1, :]))
x_tick_vals = range(0, stop = 2pi, length = 5)
x_tick_labels = ["0", "π/2", "π", "3π/2", "2π"]
plot(x, X_train[13, :], xticks = (x_tick_vals, x_tick_labels), lw = 4,
legend = false, grid = false, yaxis = false, xtickfontsize=20)

savefig("arrowhead_one.svg")
# Out:
# "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/arrowhead_one.svg"

# %%
using DelimitedFiles
using Plots
using Plots.Measures
using Statistics
using DataFrames
using StatsPlots

OBC_train = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_leg_chi16_eta02_sweeps10_train_OBC_test2.csv", ',')
PBC_left_train = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_leg_chi16_eta02_sweeps20_train_PBC_left_test2.csv", ',')
PBC_right_train = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_leg_chi16_eta02_sweeps20_train_PBC_right_test2.csv", ',')
PBC_both_train = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_leg_chi16_eta02_sweeps20_train_PBC_both_test2.csv", ',')
PBC_random_train = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_leg_chi16_eta02_sweeps20_train_PBC_ranom_test2.csv", ',') 

OBC_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_leg_chi16_eta02_sweeps10_test_OBC_test2.csv", ',')
PBC_left_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_leg_chi16_eta02_sweeps20_test_PBC_left_test2.csv", ',')
PBC_right_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_leg_chi16_eta02_sweeps20_test_PBC_right_test2.csv", ',')
PBC_both_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_leg_chi16_eta02_sweeps20_test_PBC_both_test2.csv", ',')
PBC_random_test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/angus_medical_leg_chi16_eta02_sweeps20_test_PBC_random_test2.csv", ',')    



OBC_mean = mean(OBC, dims = 1)
PBC_left_mean = mean(PBC_left, dims = 1)
PBC_right_mean = mean(PBC_right, dims = 1)
PBC_both_mean = mean(PBC_both, dims = 1)
PBC_random_mean = mean(PBC_random, dims = 1)

OBC_std = std(OBC, dims = 1)
PBC_left_std = std(PBC_left, dims = 1)
PBC_right_std = std(PBC_right, dims = 1)
PBC_both_std = std(PBC_both, dims = 1)
PBC_random_std = std(PBC_random, dims = 1)

# algorithms = ["OBC", "PBC \n Clockwise", "PBC \n Anti-Clockwise", "PBC Both", "PBC Random"]
# bar_colours = [:blue, :red, :red, :red, :red]
# means = [OBC_mean[end], PBC_right_mean[end], PBC_left_mean[end], PBC_both_mean[end], PBC_random_mean[end]]
# means = [maximum(OBC_mean), maximum(PBC_right_mean), maximum(PBC_left_mean), maximum(PBC_both_mean), maximum(PBC_random_mean)]
# #means = [mean(OBC_mean[8:end]), mean(PBC_left_mean[8:end]), mean(PBC_right_mean[8:end]), mean(PBC_both_mean[8:end]), mean(PBC_random_mean[8:end])]
# errors = [OBC_std[end], PBC_right_std[end], PBC_left_std[end], PBC_both_std[end], PBC_random_std[end]]

# # Plot the bar plot with error bars
# bar(
#     algorithms, means, yerr = errors, legend = false,
#     xlabel = "Algorithms", ylabel = "Mean Accuracy",
#     title = "Comparison of Algorithms for Medical Image Dataset: \$\\chi_{max}=16\$, \n \$\\eta=0.2\$, \$d=4\$, Legendre Encoding, Averaged Across 20 Seeds",
#     seriescolor = bar_colours,
#     lw = 4,
#     ticklinewidth = 4,
#     titlefontsize = 40, label = "", ylim = (0, 0.65),
#     size = (2000, 1200),                 # Increase plot size
#     xguidefont = font(35),             # Increase x-axis label font size
#     yguidefont = font(35),             # Increase y-axis label font size
#     xtickfont = font(30),              # Increase x-axis tick size
#     ytickfont = font(30),
#     top_margin = 15mm,
#     left_margin = 12mm,
#     bottom_margin = 17mm,
#     right_margin = 15mm,
#     grid = false
# )

# # Function to plot each row in a 5x4 subplot
# function plot_matrix_rows(matrix, matrix_2)
#     # Set up the layout with 5 rows and 4 columns of subplots
#     nrows, ncols = 5, 4
#     p = plot(layout = (nrows, ncols), size = (1200, 800))

#     # Loop through each row of the matrix
#     for i in 1:size(matrix, 1)
#         plot!(p, matrix[i, :], subplot = i, title = "Seed $i", label = "train", left_margin = 5mm, plot_title = "OBC Training and Testing Accuracy vs Sweeps for Differing Seeds")
#         plot!(p, matrix_2[i, :], subplot = i, label = "test")
#         xlabel!("Sweeps")
#         ylabel!("Acc")
#     end
#     #savefig("quickthingforben.png")
#     display(p)
# end

# # Call the function to plot the matrix
# plot_matrix_rows(OBC_train, OBC_test)

function get_testing_accuracies_at_max_train(train_matrix, test_matrix)
    nrows = size(train_matrix, 1)
    corresponding_test_accuracies = []

    # Loop through each row of the training matrix
    for i in 1:nrows
        # Find the index of the maximum training accuracy
        max_train_index = argmax(train_matrix[i, :])

        # Get the corresponding testing accuracy
        corresponding_test = test_matrix[i, max_train_index]
        
        # Append the corresponding testing accuracy to the vector
        push!(corresponding_test_accuracies, corresponding_test)
    end

    # Convert the vector to an array for averaging
    corresponding_test_accuracies = collect(corresponding_test_accuracies)

    # Compute the average of corresponding testing accuracies
    average_accuracy = mean(corresponding_test_accuracies)

    # Compute the error bar (standard deviation)
    error_bar = std(corresponding_test_accuracies)

    return average_accuracy, error_bar, corresponding_test_accuracies
end

obc_acc, obc_std, obcs = get_testing_accuracies_at_max_train(OBC_train, OBC_test)
left_acc, left_std, lefts = get_testing_accuracies_at_max_train(PBC_left_train, PBC_left_test)
right_acc, right_std, rights = get_testing_accuracies_at_max_train(PBC_right_train, PBC_right_test)
both_acc, both_std, boths = get_testing_accuracies_at_max_train(PBC_both_train, PBC_both_test)
random_acc, random_std, randoms = get_testing_accuracies_at_max_train(PBC_random_train, PBC_random_test)

accuracies = [obc_acc, right_acc, left_acc, both_acc, random_acc]
std_devs = [obc_std, right_std, left_std, both_std, random_std]
algorithms = ["OBC", "PBC \n Clockwise", "PBC \n Anti-Clockwise", "PBC Both", "PBC Random"]

# scatter plot
x = 1:length(algorithms)
colors = [:blue, :red, :red, :red, :red]
scatter(x, accuracies, yerr=std_devs, xlabel="Algorithms", ylabel="Accuracy", 
title = "Comparison of Algorithms for Medical Image Dataset: \$\\chi_{max}=16\$, \n \$\\eta=0.2\$, \$d=4\$, Legendre Encoding, Averaged Across 20 Seeds", 
    legend=false, xticks=(x, algorithms), markersize=16, label="", size=(1200, 600),
    xguidefont = 20, yguidefont = 20, xtickfont = 13, ytickfont = 13, titlefontsize = 23,
    bottom_margin = 9mm, left_margin = 7mm, top_margin = 7mm, right_margin = 7mm, marker = :diamond, seriescolor=colors)
#savefig("med_images_scatter.png")

# # box and whisker plot
# algorithms = ["OBC" "PBC \n Clockwise" "PBC \n Anti-Clockwise" "PBC Both" "PBC Random"]
# accs = [obcs rights lefts boths randoms]
# p = boxplot(algorithms, accs, 
# title = "Comparison of Algorithms for Medical Image Dataset: \$\\chi_{max}=16\$, \n \$\\eta=0.2\$, \$d=4\$, Legendre Encoding, Averaged Across 20 Seeds",
#         ylabel="Accuracy", xlabel = "Algorithm", legend=false, fillcolor=[:blue :red :red :red :red], linecolor=:black, whisker_width=0.5, lw = 2, outliers=true, marker=(:black, stroke(0)),
#         size = (1200, 600), xguidefont = 20, yguidefont = 20, xtickfont = 13, ytickfont = 13, titlefontsize = 23, bottom_margin = 9mm, left_margin = 7mm, top_margin = 7mm, right_margin = 7mm)
#         # Add violin plot on top
# violin!(p, algorithms, accs,
# fillcolor=[:blue :red :red :red :red],
# linecolor=:black, lw = 2,
# alpha=0.3)
# savefig(p, "med_images_box_violin.png")
# Out:
# ┌ Warning: Indices Base.OneTo(5) of attribute `seriescolor` does not match data indices 2:15.
# └ @ Plots /Users/angusrutherford/.julia/packages/Plots/ju9dp/src/utils.jl:141
# ┌ Info: Data contains NaNs or missing values, and indices of `seriescolor` vector do not match data indices.
# │ If you intend elements of `seriescolor` to apply to individual NaN-separated segments in the data,
# │ pass each segment in a separate vector instead, and use a row vector for `seriescolor`. Legend entries
# │ may be suppressed by passing an empty label.
# │ For example,
# │     plot([1:2,1:3], [[4,5],[3,4,5]], label=["y" ""], seriescolor=[1 2])
# └ @ Plots /Users/angusrutherford/.julia/packages/Plots/ju9dp/src/utils.jl:143
# ┌ Warning: Indices Base.OneTo(5) of attribute `fillcolor` does not match data indices 2:15.
# └ @ Plots /Users/angusrutherford/.julia/packages/Plots/ju9dp/src/utils.jl:141
# ...
