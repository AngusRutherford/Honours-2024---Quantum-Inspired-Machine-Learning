# %%
using DelimitedFiles
using Plots
using Statistics

# OBC_train_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_train_accuracy_sine_circle.csv", ',')
# OBC_test_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_test_accuracy_sine_circle.csv", ',')
# OBC_train_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_train_loss_sine_circle.csv", ',')
# OBC_test_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_test_loss_sine_circle.csv", ',')

# OBC_train_acc_mean = vec(mean(OBC_train_acc, dims = 1))
# OBC_test_acc_mean = vec(mean(OBC_test_acc, dims = 1))
# OBC_train_loss_mean = vec(mean(OBC_train_loss, dims = 1))
# OBC_test_loss_mean = vec(mean(OBC_test_loss, dims = 1))

# OBC_train_acc_std = vec(std(OBC_train_acc, dims = 1))
# OBC_test_acc_std = vec(std(OBC_test_acc, dims = 1))
# OBC_train_loss_std = vec(std(OBC_train_loss, dims = 1))
# OBC_test_loss_std = vec(std(OBC_test_loss, dims = 1))

# PBC_left_train_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_left_train_accuracy_sine_circle.csv", ',')
# PBC_left_test_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_left_test_accuracy_sine_circle.csv", ',')
# PBC_left_train_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_left_train_loss_sine_circle.csv", ',')
# PBC_left_test_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_left_test_loss_sine_circle.csv", ',')

# PBC_left_train_acc_mean = vec(mean(OBC_train_acc, dims = 1))
# PBC_left_test_acc_mean = vec(mean(OBC_test_acc, dims = 1))
# PBC_left_train_loss_mean = vec(mean(OBC_train_loss, dims = 1))
# PBC_left_test_loss_mean = vec(mean(OBC_test_loss, dims = 1))

# PBC_left_train_acc_std = vec(std(OBC_train_acc, dims = 1))
# PBC_left_test_acc_std = vec(std(OBC_test_acc, dims = 1))
# PBC_left_train_loss_std = vec(std(OBC_train_loss, dims = 1))
# PBC_left_test_loss_std = vec(std(OBC_test_loss, dims = 1))

# PBC_right_train_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_right_train_accuracy_sine_circle.csv", ',')
# PBC_right_test_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_right_test_accuracy_sine_circle.csv", ',')
# PBC_right_train_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_right_train_loss_sine_circle.csv", ',')
# PBC_right_test_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_right_test_loss_sine_circle.csv", ',')

# PBC_right_train_acc_mean = vec(mean(OBC_train_acc, dims = 1))
# PBC_right_test_acc_mean = vec(mean(OBC_test_acc, dims = 1))
# PBC_right_train_loss_mean = vec(mean(OBC_train_loss, dims = 1))
# PBC_right_test_loss_mean = vec(mean(OBC_test_loss, dims = 1))

# PBC_right_train_acc_std = vec(std(OBC_train_acc, dims = 1))
# PBC_right_test_acc_std = vec(std(OBC_test_acc, dims = 1))
# PBC_right_train_loss_std = vec(std(OBC_train_loss, dims = 1))
# PBC_right_test_loss_std = vec(std(OBC_test_loss, dims = 1))

# PBC_both_train_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_both_train_accuracy_sine_circle.csv", ',')
# PBC_both_test_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_both_test_accuracy_sine_circle.csv", ',')
# PBC_both_train_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_both_train_loss_sine_circle.csv", ',')
# PBC_both_test_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_both_test_loss_sine_circle.csv", ',')

# PBC_both_train_acc_mean = vec(mean(OBC_train_acc, dims = 1))
# PBC_both_test_acc_mean = vec(mean(OBC_test_acc, dims = 1))
# PBC_both_train_loss_mean = vec(mean(OBC_train_loss, dims = 1))
# PBC_both_test_loss_mean = vec(mean(OBC_test_loss, dims = 1))

# PBC_both_train_acc_std = vec(std(OBC_train_acc, dims = 1))
# PBC_both_test_acc_std = vec(std(OBC_test_acc, dims = 1))
# PBC_both_train_loss_std = vec(std(OBC_train_loss, dims = 1))
# PBC_both_test_loss_std = vec(std(OBC_test_loss, dims = 1))

# PBC_random_train_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_random_train_accuracy_sine_circle.csv", ',')
# PBC_random_test_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_random_test_accuracy_sine_circle.csv", ',')
# PBC_random_train_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_random_train_loss_sine_circle.csv", ',')
# PBC_random_test_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_random_test_loss_sine_circle.csv", ',')

# PBC_random_train_acc_mean = vec(mean(OBC_train_acc, dims = 1))
# PBC_random_test_acc_mean = vec(mean(OBC_test_acc, dims = 1))
# PBC_random_train_loss_mean = vec(mean(OBC_train_loss, dims = 1))
# PBC_random_test_loss_mean = vec(mean(OBC_test_loss, dims = 1))

# PBC_random_train_acc_std = vec(std(OBC_train_acc, dims = 1))
# PBC_random_test_acc_std = vec(std(OBC_test_acc, dims = 1))
# PBC_random_train_loss_std = vec(std(OBC_train_loss, dims = 1))
# PBC_random_test_loss_std = vec(std(OBC_test_loss, dims = 1))

# # plot(OBC_train_acc_mean, ribbon = OBC_train_acc_std, label = "OBC", lw = 4)
# # plot!(PBC_left_train_acc_mean, ribbon = OBC_train_acc_std, label = "PBC (left)", lw = 4)
# # plot!(PBC_right_train_acc_mean, ribbon = OBC_train_acc_std, label = "PBC (right)", lw = 4)
# # plot!(PBC_both_train_acc_mean, ribbon = OBC_train_acc_std, label = "PBC (both)", lw = 4)
# # plot!(PBC_random_train_acc_mean, ribbon = OBC_train_acc_std, label = "PBC (random)", lw = 4)
# # xlabel!("Sweeps")
# # ylabel!("Accuracy")
# # title!("Sine vs Semi Circle Mean Train Accuracies, 50 MPS \n Initialisations, \$\\eta=0.05\$, \$\\chi_{max}=30\$, Fourier, \$d=4\$")
# # savefig("sine_circle_mean_train_accs.png")

# # plot(OBC_test_acc_mean, ribbon = OBC_test_acc_std, label = "OBC", lw = 4)
# # #plot!(PBC_left_test_acc_mean, ribbon = OBC_test_acc_std, label = "PBC (left)", lw = 4)
# # #plot!(PBC_right_test_acc_mean, ribbon = OBC_test_acc_std, label = "PBC (right)", lw = 4)
# # #plot!(PBC_both_test_acc_mean, ribbon = OBC_test_acc_std, label = "PBC (both)", lw = 4)
# # #plot!(PBC_random_test_acc_mean, ribbon = OBC_test_acc_std, label = "PBC (random)", lw = 4)
# # xlabel!("Sweeps")
# # ylabel!("Accuracy")
# # title!("Sine vs Semi Circle Mean Test Accuracies, 50 MPS \n Initialisations, \$\\eta=0.05\$, \$\\chi_{max}=30\$, Fourier, \$d=4\$")
# # #savefig("sine_circle_mean_train_accs.png")


# plot(OBC_test_acc[45, :])
# plot!(PBC_left_test_acc[45, :])

swedish_OBC_train_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_swedish_leaf_train_acc.csv", ',')
swedish_OBC_test_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_swedish_leaf_test_acc.csv", ',')
swedish_OBC_train_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_swedish_leaf_train_loss.csv", ',')
swedish_OBC_test_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_swedish_leaf_test_loss.csv", ',')

swedish_random_walk_train_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/random_walk_swedish_leaf_train_acc.csv", ',')
swedish_random_walk_test_acc = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/random_walk_swedish_leaf_test_acc.csv", ',')
swedish_random_walk_train_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/random_walk_swedish_leaf_train_loss.csv", ',')
swedish_random_walk_test_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/random_walk_swedish_leaf_test_loss.csv", ',')

plot(swedish_OBC_train_acc, label = "OBC Train", lw = 4)
plot!(swedish_random_walk_train_acc, label = "Random Walk Train", lw = 4)
plot!(swedish_OBC_test_acc, label = "OBC Test", lw = 4)
plot!(swedish_random_walk_test_acc, label = "Random Walk Test", lw = 4)

plot(swedish_OBC_train_loss, label = "OBC Train", lw = 4)
plot!(swedish_random_walk_train_loss, label = "Random Walk Train", lw = 4)
plot!(swedish_OBC_test_loss, label = "OBC Test", lw = 4)
plot!(swedish_random_walk_test_loss, label = "Random Walk Test", lw = 4)
ylims!(10, 250)

# %%
using Plots
using Statistics
function two_correlation(n_samples, n_points, alpha, std_dev, correlation_index_1, correlation_index_2)
    # Validate indices
    if correlation_index_1 < 1 || correlation_index_1 > n_points || correlation_index_2 < 1 || correlation_index_2 > n_points
        error("Correlation indices must be within the range of points.")
    end

    x_min = 0
    x_max = 2π
    dx = (x_max - x_min) / n_points
    x = range(x_min, stop=x_max - dx, length=n_points)

    class_A = Matrix{Float64}(undef, n_samples, n_points)
    class_B = Matrix{Float64}(undef, n_samples, n_points)
    class_A_label = []
    class_B_label = []

    for i in 1:n_samples
        curve_A = []
        curve_B = []
        mu = sin.(x)  # Calculate mu for each x using the sine function

        for j in 1:n_points
            y_A = rand(Normal(mu[j], std_dev))  # Generate class A data
            y_B = rand(Normal(mu[j], std_dev))  # Generate class B data
            push!(curve_A, y_A)
            push!(curve_B, y_B)
        end

        # Apply specific correlation to the chosen points
        curve_A[correlation_index_2] = alpha * curve_A[correlation_index_1] + rand(Normal(mu[correlation_index_2], std_dev))
        curve_B[correlation_index_2] = -alpha * curve_B[correlation_index_1] + rand(Normal(mu[correlation_index_2], std_dev))

        class_A[i, :] = curve_A
        class_B[i, :] = curve_B
        push!(class_A_label, 0)
        push!(class_B_label, 1)
    end
    y_int = sin(x[end])
    return class_A, class_B, class_A_label, class_B_label, x, y_int
end

function scatter_plot_classes(class_A, class_B, alpha, y_int, idx1, idx2)
    # Extract specified points from class_A
    points_A_idx1 = class_A[:, idx1]
    points_A_idx2 = class_A[:, idx2]
    
    # Extract specified points from class_B
    points_B_idx1 = class_B[:, idx1]
    points_B_idx2 = class_B[:, idx2]
    
    # Determine the limits for the plot
    x_all = [points_A_idx1; points_B_idx1]
    y_all = [points_A_idx2; points_B_idx2]
    x_min, x_max = extrema(x_all)
    y_min, y_max = extrema(y_all)
    
    # Create scatter plot with transparency
    scatter(points_A_idx1, points_A_idx2, label="Class A", color=:blue, xlabel="\$X_{$idx1}\$", ylabel="\$X_{$idx2}\$", 
            legend=:right, alpha=0.6)
    scatter!(points_B_idx1, points_B_idx2, label="Class B", color=:red, alpha=0.6)
    
    # Add the lines y = alpha * x + noise_strength * y_int for the specified indices
    y_1 = alpha * points_A_idx1 .+ y_int
    y_2 = -alpha * points_B_idx1 .+ y_int
    plot!(points_A_idx1, y_1, color=:black, lw=2, label="Predicted line for Class A")
    plot!(points_B_idx1, y_2, color=:black, lw=2, label="Predicted line for Class B")

    # Adjust the plot to fill the space
    xlims!(x_min, x_max)
    ylims!(y_min, y_max)
    title!("Scatterplot Between \$X_{$idx1}\$ and \$X_{$idx2}\$ Demonstrating \n Positive and Negative Autocorrelation")
    

    # Display the plot
    display(current())
    # Optionally save the plot to a file
    # savefig("scatterplot_autocorrelation.pdf")
end

n_samples = 500
n_points = 20
alpha = 1
std_dev = 0.2
corr_ind_1 = 2
corr_ind_2 = 19
class_A, class_B, class_A_label, class_B_label, x, y_int = two_correlation(n_samples, n_points, alpha, std_dev, corr_ind_1, corr_ind_2)
function adjust_means(class_A, class_B)
    # Compute the means of each class
    mean_A = mean(class_A, dims=1)
    mean_B = mean(class_B, dims=1)

    # Compute the global mean
    global_mean = (mean_A + mean_B) / 2

    # Adjust the data
    class_A .= class_A .- mean_A .+ global_mean
    class_B .= class_B .- mean_B .+ global_mean
    
    return class_A, class_B
end

# Adjust the means after generating your data
#class_A, class_B = adjust_means(class_A, class_B)



function autocorrelation_heatmap(class_data, n_points, n_samples)
    # Initialize the autocorrelation matrix
    autocorr_matrix = zeros(n_points, n_points)
    
    # Calculate the autocorrelation matrix
    for i = 1:n_points
        for j = 1:n_points
            autocorr_matrix[i, j] = mean(class_data[:, i] .* class_data[:, j])
        end
    end

    # Subtract the mean product matrix if necessary
    # Example using sin(x) values as mean, replace with actual mean if available
    x_min = 0
    x_max = 2π
    dx = (x_max - x_min) / n_points
    x_values = range(x_min, stop=x_max - dx, length=n_points) # Ensure this matches how class_data was generated
    mean_product_matrix = [sin(x_values[i]) * sin(x_values[j]) for i = 1:n_points, j = 1:n_points]
    autocorr_matrix .-= mean_product_matrix

    return autocorr_matrix
end

function plot_heatmap(matrix, title)
    heatmap(matrix, color=:thermal, title=title, aspect_ratio=:equal)
end

automat = autocorrelation_heatmap(class_A-class_B, 20, 500)
#plot_heatmap(automat, "Hey")
#scatter_plot_classes(class_A, class_B, )
plot(vec(mean(class_A, dims = 1)), lw = 4)
plot!(vec(mean(class_B, dims = 1)), lw = 4)
# scatter_plot_classes(class_A, class_B, alpha, y_int, 9, 10)

# writedlm("guassian_curves_500_10_1_0.1_class_A_v2.csv", class_A, ",")
# writedlm("guassian_curves_500_10_1_0.1_class_A_labels_v2.csv", class_A_labels, ",")
# writedlm("guassian_curves_500_10_1_0.1_class_B_v2.csv", class_B, ",")
# writedlm("guassian_curves_500_10_1_0.1_class_B_labels_v2.csv", class_B_labels, ",")

# %%
plot(vec(mean(class_A, dims = 1)), lw = 4)
plot!(vec(mean(class_B, dims = 1)), lw = 4)

# %%
using Plots
using Statistics
using Distributions

function two_correlation(n_samples, n_points, alpha1, alpha2, std_dev, correlation_index_1, correlation_index_2, correlation_index_3, correlation_index_4)
    # Validate indices for both sets of correlations
    if any(i -> i < 1 || i > n_points, [correlation_index_1, correlation_index_2, correlation_index_3, correlation_index_4])
        error("All correlation indices must be within the range of points.")
    end

    x_min = 0
    x_max = 2π
    dx = (x_max - x_min) / n_points
    x = range(x_min, stop=x_max - dx, length=n_points)

    class_A = Matrix{Float64}(undef, n_samples, n_points)
    class_B = Matrix{Float64}(undef, n_samples, n_points)
    class_A_label = []
    class_B_label = []

    for i = 1:n_samples
        curve_A = []
        curve_B = []
        mu = sin.(x)  # Calculate mu for each x using the sine function

        for j = 1:n_points
            y_A = rand(Normal(mu[j], std_dev))  # Generate class A data
            y_B = rand(Normal(mu[j], std_dev))  # Generate class B data
            push!(curve_A, y_A)
            push!(curve_B, y_B)
        end

        # Apply specific correlation to the chosen points
        curve_A[correlation_index_2] = alpha1 * curve_A[correlation_index_1] + rand(Normal(mu[correlation_index_2], std_dev))
        curve_B[correlation_index_2] = -alpha1 * curve_B[correlation_index_1] + rand(Normal(mu[correlation_index_2], std_dev))

        curve_A[correlation_index_4] = alpha2 * curve_A[correlation_index_3] + rand(Normal(mu[correlation_index_4], std_dev))
        curve_B[correlation_index_4] = -alpha2 * curve_B[correlation_index_3] + rand(Normal(mu[correlation_index_4], std_dev))

        class_A[i, :] = curve_A
        class_B[i, :] = curve_B
        push!(class_A_label, 0)
        push!(class_B_label, 1)
    end
    y_int = sin(x[end])
    return class_A, class_B, class_A_label, class_B_label, x, y_int
end


n_samples = 500
n_points = 20
alpha1 = 5
alpha2 = 5
std_dev = 0.2
corr_ind_1 = 2
corr_ind_2 = 19
corr_ind_3 = 10
corr_ind_4 = 11

class_A, class_B, class_A_label, class_B_label, x, y_int = two_correlation(n_samples, n_points, alpha1, alpha2, std_dev, corr_ind_1, corr_ind_2, corr_ind_3, corr_ind_4)
class_A, class_B = adjust_means(class_A, class_B)
automat = autocorrelation_heatmap(class_A, 20, 500)
plot_heatmap(automat, "Hey")

# plot(vec(mean(class_A, dims = 1)), lw = 4)
# plot!(vec(mean(class_B, dims = 1)), lw = 4)


writedlm("guassian_curves_500_10_1_0.1_class_A_v2.csv", class_A, ",")
writedlm("guassian_curves_500_10_1_0.1_class_A_labels_v2.csv", class_A_labels, ",")
writedlm("guassian_curves_500_10_1_0.1_class_B_v2.csv", class_B, ",")
writedlm("guassian_curves_500_10_1_0.1_class_B_labels_v2.csv", class_B_labels, ",")

# %%
using Distributions
using Plots
using Plots.PlotMeasures
using DelimitedFiles

function generate_classes(n_samples, n_points, alpha, noise_strength)
    x_min = 0
    x_max = 2π
    dx = (x_max - x_min) / (n_points)
    x = range(x_min, stop=x_max - dx, length=n_points)

    class_A = Matrix{Float64}(undef, n_samples, n_points)
    class_B = Matrix{Float64}(undef, n_samples, n_points)
    class_A_label = []
    class_B_label = []

    for i in 1:n_samples
        curve_A = []
        curve_B = []
        mu = sin.(x)  # Calculate mu for each x using the sine function

        for j in 1:length(mu)-1
            y_A = rand(Normal(mu[j], 0.1))  # Generate class A data
            #y_A = rand(Normal(mu[j], 1))
            y_B = rand(Normal(mu[j], 0.1))  # Generate class B data
            #y_B = rand(Normal(mu[j], 1))
            push!(curve_A, y_A)
            push!(curve_B, y_B)
        end
        
        # Handle the last point with specific dependency on the first point
        mu_last = mu[end]
        y_A_last = alpha * curve_A[1] + rand(Normal(mu_last, 0.1))
        y_B_last = -alpha * curve_B[1] + rand(Normal(mu_last, 0.1))
        push!(curve_A, y_A_last)
        push!(curve_B, y_B_last)

        class_A[i, :] = curve_A
        class_B[i, :] = curve_B
        push!(class_A_label, 0)
        push!(class_B_label, 1)
    end
    y_int = sin(x[end])
    return class_A, class_B, class_A_label, class_B_label, x, y_int
end


# function plot_distributions_grid(class_A, n_points, rows, cols, x_values, alpha)
#     # Create a plot with subplots arranged in a grid of `rows` x `cols`
#     p = plot(layout=(rows, cols), size=(1500, 1500), left_margin = 5mm)  # Adjust size as needed
#     for j in 1:n_points
#         column_values = class_A[:, j]
#         x = x_values[j]
#         mu = sin(x)
#         #@show mu
#         # Each subplot represents the distribution at one point, histogram entry in legend is turned off
#         histogram!(p, column_values, normalize=true, subplot=j, title="Distribution of Point $j",
#                    xlabel="Value", ylabel="Density", legend=true, label = "")
#         # Plot the normal distribution curve and use legend to indicate mean
#         if j == n_points
#             sigma = sqrt(alpha^2+1)
#             mu = sin(x_values[n_points])
#             plot!(p, x -> pdf(Normal(0, sigma), x), lw=2, c=:red, label="μ=0.0, σ=$(round(sigma, digits=2))", loc=:best, subplot=j)
#         else
#             plot!(p, x -> pdf(Normal(mu, 1), x), lw=2, c=:red, label="μ=$(round(mu, digits=2)), σ=1", loc=:best, subplot=j)
#         end
#     end
    
#     display(p)
#     return p
# end

function plot_distributions_grid(class_A, n_points, rows, cols, x_values, alpha, noise_strength)
    p = plot(layout=(rows, cols), size=(1500, 1500), left_margin = 5mm)
    
    for j in 1:n_points
        column_values = class_A[:, j]
        x = x_values[j]

        if j == n_points
            sigma = noise_strength * sqrt(alpha^2+1)
            mu = sin(x)*(noise_strength + 1) # Explicitly setting mean to zero for the last point
        else
            sigma = noise_strength  # Standard deviation for other points
            mu = sin(x)*(noise_strength + 1)
        end

        # Plot histogram
        histogram!(p, column_values, normalize=true, subplot=j,
                   title="Distribution of Point $j", xlabel="Value", ylabel="Density", legend=:best, label = "")

        # Calculate plot range for the curve
        xmin, xmax = extrema(column_values)  # Get the range of the histogram data
        x_range = range(xmin - 1 * sigma, xmax + 1 * sigma, length=300)  # Extend range to cover tails
        
        # Plot normal distribution curve
        normal_curve = pdf.(Normal(mu, sigma), x_range)
        plot!(p, x_range, normal_curve, lw=2, c=:red, label="μ=$(round(mu, digits=2)), σ=$(round(sigma, digits=2))", subplot=j)
    end

    #display(p)
    return p
end


# class_A, class_B, class_A_label, class_B_label, x, y_int = generate_classes(500, 20, 2, 0.1)
# myfig = plot_distributions_grid(class_B, 20, 5, 4, x, 2, 0.1)

# writedlm("guassian_curves_500_20_2_class_A.csv", class_A, ",")
# writedlm("guassian_curves_500_20_2_class_A_labels.csv", class_A_label, ",")
# writedlm("guassian_curves_500_20_2_class_B.csv", class_B, ",")
# writedlm("guassian_curves_500_20_2_class_B_labels.csv", class_B_label, ",")
#savefig(myfig, "distributions_alpha=2.png")

# Function to create scatter plot

function scatter_plot_classes(class_A, class_B, alpha, y_int, noise_strength)
    # Extract the first and last points from class_A
    first_points_A = class_A[:, 1]
    last_points_A = class_A[:, end]
    
    # Extract the first and last points from class_B
    first_points_B = class_B[:, 1]
    last_points_B = class_B[:, end]
    
    # Determine the limits for the plot
    x_all = [first_points_A; first_points_B]
    y_all = [last_points_A; last_points_B]
    x_min, x_max = extrema(x_all)
    y_min, y_max = extrema(y_all)
    
    # Create scatter plot with transparency
    scatter(first_points_A, last_points_A, label="Class A", color=:blue, xlabel="\$X_{1}\$", ylabel="\$X_{N}\$", 
            legend=:right, alpha=2)
    scatter!(first_points_B, last_points_B, label="Class B", color=:red, alpha=2)
    
    # Add the line y = alpha * x
    y_1 = alpha*first_points_A .+ noise_strength*y_int
    y_2 = -alpha*first_points_B .+ noise_strength*y_int
    plot!(first_points_A, y_1, color=:black, lw = 4, label = "\$y=\\alpha x\$")
    plot!(first_points_B, y_2, color=:black, lw = 4, label = "\$y=-\\alpha x\$")
    # plot!([x_min, x_max], [alpha*x_min + y_int, alpha*x_max + y_int], label="\$y = \\alpha x+C\\eta\$", color=:black, lw=2)
    # plot!([x_min, x_max], [-alpha*x_min + y_int, -alpha*x_max + y_int], label="\$y = -\\alpha x+C\\eta\$", color=:black, lw=2)

    # Adjust the plot to fill the space
    xlims!(x_min, x_max)
    ylims!(y_min, y_max)
    title!("Scatterplot Between \$X_{1}\$ and \$X_{N}\$ Demonstrating \n Positive and Negative Autocorrelation")
    

    # Display the plot
    display(current())
    # savefig("scatterplot_500_20_1_0.1_talk.png")
    # savefig("scatterplot_500_20_1_0.1_talk.pdf")
    #return first_points_A
end



#scatter_plot_classes(class_A, class_B, 2)
# Example usage with generated data (ensure you have class_A and class_B available):
# Generate the classes (assumes you already have this function defined)
# class_A, class_B, class_A_label, class_B_label = generate_classes(50, 20, 0.8)

# Create the scatter plot
# scatter_plot_classes(class_A, class_B, 0.8)

# %%
n_samples = 500
n_points = 20
alpha = 5
noise_strength = 1
rows = 5
cols = 2



class_A, class_B, class_A_labels, class_B_labels, x_values, y_int = generate_classes(n_samples, n_points, alpha, noise_strength)

# writedlm("guassian_curves_500_10_1_0.1_class_A.csv", class_A, ",")
# writedlm("guassian_curves_500_10_1_0.1_class_A_labels.csv", class_A_label, ",")
# writedlm("guassian_curves_500_10_1_0.1_class_B.csv", class_B, ",")
# writedlm("guassian_curves_500_10_1_0.1_class_B_labels.csv", class_B_label, ",")

#myfig = plot_distributions_grid(class_B, n_points, rows, cols, x_values, alpha, noise_strength)
# savefig(myfig, "distributions_500_10_1_0.1.png")
# savefig(myfig, "distributions_500_10_1_0.1.pdf")

# means = mean(class_A, dims = 1)
# stds = std(class_A, dims = 1)
#hey = scatter_plot_classes(class_A, class_B, alpha, y_int, noise_strength)
#extrema(hey)
# writedlm("guassian_curves_500_20_1_0_class_A.csv", class_A, ",")
# writedlm("guassian_curves_500_20_1_0_class_A_labels.csv", class_A_label, ",")
# writedlm("guassian_curves_500_20_1_0_class_B.csv", class_B, ",")
# writedlm("guassian_curves_500_20_1_0_class_B_labels.csv", class_B_label, ",")

# means = mean(class_A, dims = 1)
# means_2 = mean(class_B, dims = 1)
# means = vec(means)
# means_2 = vec(means_2)
# plot(means)
# plot!(means_2)

# class_A = hcat([circshift(class_A[i, :], 10) for i in 1:size(class_A, 1)]...)
# class_A = Matrix(transpose(class_A))
# class_B = hcat([circshift(class_B[i, :], 10) for i in 1:size(class_B, 1)]...)
# class_B = Matrix(transpose(class_B))

matrix_1 = zeros(20, 20)
for i = 1:20
    for j = 1:20
        sample_total = []
        for sample = 1:500
            term = (1/500)*(class_A[sample, i] * class_A[sample, j])
            push!(sample_total, term)
        end
        matrix_1[i, j] = sum(sample_total)
    end
end

matrix_2 = zeros(20, 20)
for i = 1:20
    for j = 1:20
        sample_total = []
        for sample = 1:500
            term = (1/500)*(class_B[sample, i] * class_B[sample, j])
            push!(sample_total, term)
        end
        matrix_2[i, j] = sum(sample_total)
    end
end

second_matrix = zeros(20, 20)
for i = 1:20
    for j = 1:20
        second_matrix[i, j] = (sin(x_values[i]) * sin(x_values[j]))
    end
end

class_A_matrix = matrix_1 .- second_matrix
class_B_matrix = matrix_2 .- second_matrix

combined = class_A_matrix .- class_B_matrix

thingy = heatmap(class_A_matrix, color=:thermal, axis=false, aspect_ratio=:equal)

plot(vec(mean(class_A, dims = 1)), lw = 4)
plot!(vec(mean(class_B, dims = 1)), lw = 4)


writedlm("guassian_curves_500_10_1_0.1_class_A_v2.csv", class_A, ",")
writedlm("guassian_curves_500_10_1_0.1_class_A_labels_v2.csv", class_A_labels, ",")
writedlm("guassian_curves_500_10_1_0.1_class_B_v2.csv", class_B, ",")
writedlm("guassian_curves_500_10_1_0.1_class_B_labels_v2.csv", class_B_labels, ",")

plot(thingy)

# %%
using Random, Distributions

# Function to generate synthetic data
function generate_synthetic_data(n_samples, sequence_length)
    # Define the parameters for the distribution
    mean_sequence = sin.(range(0, stop=2π, length=sequence_length))
    std_dev = 0.5
    distribution = Normal(0, std_dev)

    # Prepare containers for the dataset
    data = zeros(n_samples, sequence_length)
    labels = zeros(Int, n_samples)

    # Generate data
    for i in 1:n_samples
        # Randomly decide the class
        class_label = rand([0, 1]) # 0 for class A, 1 for class B
        sequence = mean_sequence .+ rand(distribution, sequence_length)

        # Introduce correlation between the first and last points
        if class_label == 0
            sequence[end] = sequence[1] + rand(Normal(0, 0.1)) # Positive correlation
        else
            sequence[end] = -sequence[1] + rand(Normal(0, 0.1)) # Negative correlation
        end

        # Store the generated data
        data[i, :] = sequence
        labels[i] = class_label
    end

    return data, labels
end

# Example usage
n_samples = 1000
sequence_length = 100
data, labels = generate_synthetic_data(n_samples, sequence_length)



# Now, `data` contains your dataset, and `labels` contains the class labels.

matrix_1 = zeros(20, 20)
for i = 1:20
    for j = 1:20
        sample_total = []
        for sample = 1:500
            term = (1/500)*(class_A[sample, i] * class_A[sample, j])
            push!(sample_total, term)
        end
        matrix_1[i, j] = sum(sample_total)
    end
end

matrix_2 = zeros(20, 20)
for i = 1:20
    for j = 1:20
        sample_total = []
        for sample = 1:500
            term = (1/500)*(class_B[sample, i] * class_B[sample, j])
            push!(sample_total, term)
        end
        matrix_2[i, j] = sum(sample_total)
    end
end

second_matrix = zeros(20, 20)
for i = 1:20
    for j = 1:20
        second_matrix[i, j] = (sin(x_values[i]) * sin(x_values[j]))
    end
end

class_A_matrix = matrix_1 .- second_matrix
class_B_matrix = matrix_2 .- second_matrix

combined = class_A_matrix .- class_B_matrix

thingy = heatmap(class_A_matrix, color=:thermal, axis=false, aspect_ratio=:equal)

# writedlm("class1_data.csv", class_A, ",")
# writedlm("class1_labels.csv", class_B_label, ",")
# writedlm("class2_data.csv", class_A, ",")
# writedlm("class2_labels.csv", class_B_label, ",")
# plot(vec(mean(class_A, dims = 1)), lw = 4)
# plot!(vec(mean(class_B, dims = 1)), lw = 4)
#plot(thingy)

# %%
using DelimitedFiles
using DataFrames
include("RealRealHighDimension.jl")
# file_path_train = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/BirdChicken_TRAIN.txt"
# file_path_test = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/BirdChicken_TEST.txt"

# file_path_train = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/SwedishLeaf_TRAIN.txt"
# file_path_test = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/SwedishLeaf_TEST.txt"

# file_path_train = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/MedicalImages_TRAIN.txt"
# file_path_test = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/MedicalImages_TEST.txt"

file_path_train = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/Fish_TRAIN.txt"
file_path_test = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/Fish_TEST.txt"

# file_path_train = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/ArrowHead_TRAIN.txt"
# file_path_test = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/ArrowHead_TEST.txt"
#Read and parse the data
parsed_data_train = read_and_parse(file_path_train)
parsed_data_test = read_and_parse(file_path_test)

# Convert the list of lists into a DataFrame
training_data = DataFrame(parsed_data_train, :auto)
testing_data = DataFrame(parsed_data_test, :auto)

training_data_matrix = Matrix{Float64}(training_data[2:end, :])
training_data_matrix = Matrix(transpose(training_data_matrix))

testing_data_matrix = Matrix{Float64}(testing_data[2:end, :])
testing_data_matrix = Matrix(transpose(testing_data_matrix))
fish_119 = training_data_matrix[119, :]

using Plots

function reconstruct_shape(distances)
    n = length(distances)
    min_distance = minimum(distances)
    offset = min_distance < 0 ? abs(min_distance) : 0

    adjusted_distances = distances .+ offset
    radii = (adjusted_distances)

    angles = range(0, stop=2π, length=n)
    x = radii .* cos.(angles)
    y = radii .* sin.(angles)

    return x, y
end

function plot_shape(distances)
    x, y = reconstruct_shape(distances)
    
    p = plot(aspect_ratio=:equal, legend=false, lw = 10)
    plot!(p, x, y, label="Shape Outline", color=:blue)
    #scatter!(p, [0], [0], label="Center", color=:red, markersize=6)
    
    title!(p, "Reconstructed Shape")
    xlabel!(p, "X")
    ylabel!(p, "Y")
    
    return p
end

# push!(fish_4, fish_4[end])
#angles = range(0, stop=2π, length=length(fish_119)) 
n = length(fish_119)
min_distance = minimum(fish_119)
offset = min_distance < 0 ? abs(min_distance) : 0
fish_119 = fish_119 .+ offset
radii = fish_119 
angles = range(0, stop=2π, length=n)
x_fish = radii .* cos.(angles)
y_fish = radii .* sin.(angles)
x_fish_1 = radii[1:100] .* cos.(angles[1:100])
y_fish_1 = radii[1:100] .* sin.(angles[1:100])
x_fish_2 = radii[100:320] .* cos.(angles[100:320])
y_fish_2 = radii[100:320] .* sin.(angles[100:320])
x_fish_3 = radii[321:end] .* cos.(angles[321:end])
y_fish_3 = radii[321:end] .* sin.(angles[321:end])
p = plot(x_fish_1, y_fish_1, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :yellow))
p = plot!(x_fish_2, y_fish_2, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :blue))
p = plot!(x_fish_3, y_fish_3, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :yellow))
p = plot!([x_fish_3[1], x_fish_1[end]], [y_fish_3[1]+0, y_fish_1[end]-0], color = :blue, fill = (0, :yellow), lw = 4)
p = scatter!([x_fish_1[end]+0.01], [y_fish_1[end]-0.01], color = :black, markersize = 2)
p = scatter!([x_fish_1[end]-0.01], [y_fish_1[end]+0.01], color = :black, markersize = 2)
p = scatter!([x_fish_3[1]], [y_fish_3[1]], color = :black, markersize = 2)
p = plot!([0.08, 0.1], [0, 0.25], color = :yellow, lw = 4)
p = plot!([0.04, x_fish_3[128]], [0.15, y_fish_3[128]], color = :black, lw = 4)
p = plot!([0.022, x_fish_3[100]], [0.07, y_fish_3[100]], color = :black, lw = 4)
p = plot!([0.068, x_fish_1[10]], [0.25, y_fish_1[10]], color = :black, lw = 4)
eye_radius = 0.3
x_eye = eye_radius * cos.(angles)
y_eye = eye_radius * sin.(angles)
plot!(-2.2 .+ x_eye, 1 .+ y_eye, fill=(0, :silver), color = :black, lw = 4)
p2 = plot(x_fish_1, y_fish_1, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, legend = false, axis_ratio=:equal)
p2 = plot!(x_fish_2, y_fish_2, lw = 4, color = :black)
p2 = plot!(x_fish_3, y_fish_3, lw = 4, color = :black)
#scatter!(p, [x_fish[320]], [y_fish[320]], color = :red, markersize = 10)
# for i = 1:33
#     plot!(p, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 1, color = :black)
# end
layout = @layout [grid(2, 1)]
combined_plot = plot(p, p2, layout = layout)
display(combined_plot)

# for i = 1:173
#     t = plot_shape(training_data_matrix[i, :])
#     display(t)
# end

#1-99
#100-319
#320-463 (end)

# %%
using Plots
using Plots.Measures

# Parameters for the plot
θ = range(0, stop=2π, length=1000)  # Range of angles
radius = 1  # Radius of the circle
inner_radius = 0.3  # Radius of the inner circle
amplitude = 0.3  # Amplitude of the sine wave
n = 10  # Frequency multiplier
# Calculate the coordinates for the main modulated circle plot
x_outer = (radius .+ amplitude .* sin.(n*θ)) .* cos.(θ)
y_outer = (radius .+ amplitude .* sin.(n*θ)) .* sin.(θ)
x_inner = inner_radius * cos.(θ)
y_inner = inner_radius * sin.(θ)
x_flat = θ
y_flat = amplitude .* sin.(n*θ) .+ 0.35
x_tick_vals = range(0, stop = 2pi, length = 5)
x_tick_labels = ["0", "π/2", "π", "3π/2", "2π"]

# Plot the outer shape with red fill, ensuring it's below the inner circle
p1 = plot(x_outer, y_outer, fill=(0, :purple), legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black)
plot!(x_inner, y_inner, fill = (0, :yellow), dpi = 700)
p2 = plot(x_outer, y_outer, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black)
for i = 1:40
    plot!(p2, [0, x_outer[25*i]], [0, y_outer[25*i]], lw = 1, color = :black)
end
p3 = plot(x_flat, y_flat, xticks = (x_tick_vals, x_tick_labels), lw = 4, ylim = (0, amplitude + 0.4), yaxis = false, grid = false,
    legend = false, xtickfontsize=30, color = :black, bottom_margin = 11mm)
layout = @layout [grid(1, 3)]
combined_plot = plot(p1, p2, p3, layout = layout, size = (2000, 600))
display(combined_plot)
# # Plot the inner circle with yellow fill
# plot!(x_inner, y_inner, fill=(0, :yellow), label="", linecolor=:yellow)

savefig("flower_test.png")

# %%
#flower and fish together
using DelimitedFiles
using Plots
using Plots.Measures
using DataFrames

function read_and_parse(file_path)
    data = []
    open(file_path, "r") do file
        for line in eachline(file)
            # Use regex to split on any sequence of whitespace and filter out empty strings
            entries = filter(!isempty, split(line, r"\s+"))
            # Convert each entry to Float64, replacing empty strings or malformed data with NaN
            parsed_entries = [isempty(s) ? NaN : parse(Float64, s) for s in entries]
            push!(data, parsed_entries)
        end
    end
    return data
end

file_path_train = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/Fish_TRAIN.txt"
file_path_test = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/Fish_TEST.txt"

# file_path_train = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/ArrowHead_TRAIN.txt"
# file_path_test = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/ArrowHead_TEST.txt"
#Read and parse the data
parsed_data_train = read_and_parse(file_path_train)
parsed_data_test = read_and_parse(file_path_test)

# Convert the list of lists into a DataFrame
training_data = DataFrame(parsed_data_train, :auto)
testing_data = DataFrame(parsed_data_test, :auto)

training_data_matrix = Matrix{Float64}(training_data[2:end, :])
training_data_matrix = Matrix(transpose(training_data_matrix))

testing_data_matrix = Matrix{Float64}(testing_data[2:end, :])
testing_data_matrix = Matrix(transpose(testing_data_matrix))
fish_119 = training_data_matrix[119, :]

fish_119 = training_data_matrix[119, :]
θ_fish = range(0, stop=2π, length=length(fish_119))  # Range of angles
θ_flower = range(0, stop=2π, length=1000)  # Range of angles
angles = range(0, stop = 2pi, length = 1000)
radius = 1  # Radius of the circle
inner_radius = 0.3  # Radius of the inner circle
amplitude = 0.3  # Amplitude of the sine wave
n = 10  # Frequency multiplier
# Calculate the coordinates for the main modulated circle plot
x_outer = (radius .+ amplitude .* sin.(n*θ_flower)) .* cos.(θ_flower)
y_outer = (radius .+ amplitude .* sin.(n*θ_flower)) .* sin.(θ_flower)
x_inner = inner_radius * cos.(θ_flower)
y_inner = inner_radius * sin.(θ_flower)
x_flat = θ_flower
y_flat = amplitude .* sin.(n*θ_flower) .+ 0.35
x_tick_vals = range(0, stop = 2pi, length = 5)
x_tick_labels = ["0", "π/2", "π", "3π/2", "2π"]

min_distance = minimum(fish_119)
offset = min_distance < 0 ? abs(min_distance) : 0
fish_119 = fish_119 .+ offset
x_fish_1 = fish_119[1:100] .* cos.(θ_fish[1:100])
y_fish_1 = fish_119[1:100] .* sin.(θ_fish[1:100])
x_fish_2 = fish_119[100:320] .* cos.(θ_fish[100:320])
y_fish_2 = fish_119[100:320] .* sin.(θ_fish[100:320])
x_fish_3 = fish_119[320:end] .* cos.(θ_fish[320:end])
y_fish_3 = fish_119[320:end] .* sin.(θ_fish[320:end])
x_fish = fish_119 .* cos.(θ_fish)
y_fish = fish_119 .* sin.(θ_fish)
eye_radius = 0.3
pupil_radius = 0.1
x_eye = eye_radius * cos.(angles)
y_eye = eye_radius * sin.(angles)
x_pupil = pupil_radius * cos.(angles)
y_pupil = pupil_radius * sin.(angles)

# p = plot(x_fish_1, y_fish_1, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :yellow))
# p = plot!(x_fish_2, y_fish_2, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :green))
# p = plot!(x_fish_3, y_fish_3, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :yellow))
# p = plot!([x_fish_3[1], x_fish_1[end]], [y_fish_3[1]+0, y_fish_1[end]-0], color = :yellow, fill = (0, :yellow))
# p = scatter!([x_fish_1[end]], [y_fish_1[end]], color = :black, markersize = 3)
# p = scatter!([x_fish_3[1]], [y_fish_3[1]], color = :black, markersize = 2)
# p = plot!([0.04, x_fish_3[128]], [0.15, y_fish_3[128]], color = :black, lw = 4)
# p = plot!([0.022, x_fish_3[100]], [0.07, y_fish_3[100]], color = :black, lw = 4)
# p = plot!([0.068, x_fish_1[10]], [0.25, y_fish_1[10]], color = :black, lw = 4)

p1 = plot(x_outer, y_outer, fill=(0, :purple), legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal)
plot!(x_inner, y_inner, fill = (0, :yellow))
p2 = plot(x_outer, y_outer, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal)
for i = 1:40
    if i == 19
        plot!(p2, [0, x_outer[25*i]], [0, y_outer[25*i]], lw = 4, color = :blue, arrow = true)
    elseif i == 33
        plot!(p2, [0, x_outer[25*i]], [0, y_outer[25*i]], lw = 4, color = :lime, arrow = true)
    elseif i == 40
        plot!(p2, [0, x_outer[25*i]], [0, y_outer[25*i]], lw = 4, color = :red, arrow = true)
    else
        plot!(p2, [0, x_outer[25*i]], [0, y_outer[25*i]], lw = 1, color = :black)
    end
end
p3 = plot(x_flat, y_flat, xticks = (x_tick_vals, x_tick_labels), lw = 4, ylim = (-0.1, amplitude+0.4), yaxis = false, grid = false,
    legend = false, xtickfontsize=30, color = :black, bottom_margin = 11mm)
plot!(p3, [x_flat[1], x_flat[1]], [-0.1, y_flat[1]], arrow = true, lw = 4, linecolor = :red)
plot!(p3, [x_flat[475], x_flat[475]], [-0.1, y_flat[475]], arrow = true, lw = 4, linecolor = :blue)
plot!(p3, [x_flat[826], x_flat[826]], [-0.1, y_flat[826]], arrow = true, lw = 4, linecolor = :lime)

p4 = plot(x_fish_1, y_fish_1, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :yellow))
p4 = plot!(x_fish_2, y_fish_2, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :blue))
p4 = plot!(x_fish_3, y_fish_3, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :yellow))
p4 = plot!([x_fish_3[1], x_fish_1[end]], [y_fish_3[1]+0, y_fish_1[end]-0], color = :blue, fill = (0, :yellow), lw = 4)
p4 = scatter!([x_fish_1[end]+0.01], [y_fish_1[end]-0.01], color = :black, markersize = 2)
p4 = scatter!([x_fish_1[end]-0.01], [y_fish_1[end]+0.01], color = :black, markersize = 2)
p4 = scatter!([x_fish_3[1]], [y_fish_3[1]], color = :black, markersize = 2)
p4 = plot!([0.08, 0.1], [0, 0.25], color = :yellow, lw = 4)
p4 = plot!([0.04, x_fish_3[128]], [0.15, y_fish_3[128]], color = :black, lw = 4)
p4 = plot!([0.022, x_fish_3[100]], [0.07, y_fish_3[100]], color = :black, lw = 4)
p4 = plot!([0.068, x_fish_1[10]], [0.25, y_fish_1[10]], color = :black, lw = 4)
plot!(-2.2 .+ x_eye, 1 .+ y_eye, fill=(0, :silver), color = :black, lw = 4)
plot!(-2.2 .+ x_pupil, 1 .+ y_pupil, fill = (0, :black), color = :black)
p5 = plot(x_fish, y_fish, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, legend = false, axis_ratio=:equal)
for i = 1:33
    if i == 7
        plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 4, color = :red, arrow = true)
    elseif i == 14
        plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 4, color = :blue, arrow = true)
    elseif i == 31
        plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 4, color = :lime, arrow = true)
    else
        plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 1, color = :black)
    end
end
p6 = plot(θ_fish, fish_119, xticks = (x_tick_vals, x_tick_labels), ylim = (-0.5, maximum(fish_119) + 0.5), lw = 4, yaxis = false, grid = false,
    legend = false, xtickfontsize=30, color = :black, bottom_margin = 11mm)
plot!(p6, [θ_fish[98], θ_fish[98]], [-0.5, fish_119[98]], arrow = true, lw = 4, linecolor = :red)
plot!(p6, [θ_fish[196], θ_fish[196]], [-0.5, fish_119[196]], arrow = true, lw = 4, linecolor = :blue)
plot!(p6, [θ_fish[434], θ_fish[434]], [-0.5, fish_119[434]], arrow = true, lw = 4, linecolor = :lime)

layout = @layout [grid(2, 3)]
combined_plot = plot(p1, p2, p3, p4, p5, p6, layout = layout, size = (2500, 1400), right_margin = 11mm)
#display(combined_plot)

# savefig("flower_and_fish_PLEASE.pdf")
# Out:
# "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/flower_and_fish_PLEASE.pdf"

# %%
using DelimitedFiles
using Plots
using DataFrames
using LaTeXStrings
pgfplotsx()  # Switch to the PGFPlotsX backend

function read_and_parse(file_path)
    data = []
    open(file_path, "r") do file
        for line in eachline(file)
            entries = filter(!isempty, split(line, r"\s+"))
            parsed_entries = [isempty(s) ? NaN : parse(Float64, s) for s in entries]
            push!(data, parsed_entries)
        end
    end
    return data
end

file_path_train = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/Fish_TRAIN.txt"
file_path_test = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/Fish_TEST.txt"

# file_path_train = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/ArrowHead_TRAIN.txt"
# file_path_test = "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/datasets/ArrowHead_TEST.txt"
#Read and parse the data
parsed_data_train = read_and_parse(file_path_train)
parsed_data_test = read_and_parse(file_path_test)

# Convert the list of lists into a DataFrame
training_data = DataFrame(parsed_data_train, :auto)
testing_data = DataFrame(parsed_data_test, :auto)

training_data_matrix = Matrix{Float64}(training_data[2:end, :])
training_data_matrix = Matrix(transpose(training_data_matrix))

testing_data_matrix = Matrix{Float64}(testing_data[2:end, :])
testing_data_matrix = Matrix(transpose(testing_data_matrix))
fish_119 = training_data_matrix[119, :]

fish_119 = training_data_matrix[119, :]
θ_fish = range(0, stop=2π, length=length(fish_119))  # Range of angles
θ_flower = range(0, stop=2π, length=1000)  # Range of angles
angles = range(0, stop = 2pi, length = 1000)
radius = 1  # Radius of the circle
inner_radius = 0.3  # Radius of the inner circle
amplitude = 0.3  # Amplitude of the sine wave
n = 10  # Frequency multiplier
# Calculate the coordinates for the main modulated circle plot
x_outer = (radius .+ amplitude .* sin.(n*θ_flower)) .* cos.(θ_flower)
y_outer = (radius .+ amplitude .* sin.(n*θ_flower)) .* sin.(θ_flower)
x_inner = inner_radius * cos.(θ_flower)
y_inner = inner_radius * sin.(θ_flower)
x_flat = θ_flower
y_flat = amplitude .* sin.(n*θ_flower) .+ 0.35
x_tick_vals = range(0, stop = 2pi, length = 5)
#x_tick_vals = [0, π/2, π, 3π/2, 2π]
x_tick_labels = ["0", L"\frac{\pi}{2}", L"\pi", L"\frac{3\pi}{2}", L"2\pi"]

min_distance = minimum(fish_119)
offset = min_distance < 0 ? abs(min_distance) : 0
fish_119 = fish_119 .+ offset
x_fish_1 = fish_119[1:100] .* cos.(θ_fish[1:100])
y_fish_1 = fish_119[1:100] .* sin.(θ_fish[1:100])
x_fish_2 = fish_119[100:320] .* cos.(θ_fish[100:320])
y_fish_2 = fish_119[100:320] .* sin.(θ_fish[100:320])
x_fish_3 = fish_119[320:end] .* cos.(θ_fish[320:end])
y_fish_3 = fish_119[320:end] .* sin.(θ_fish[320:end])
x_fish = fish_119 .* cos.(θ_fish)
y_fish = fish_119 .* sin.(θ_fish)
eye_radius = 0.3
pupil_radius = 0.1
x_eye = eye_radius * cos.(angles)
y_eye = eye_radius * sin.(angles)
x_pupil = pupil_radius * cos.(angles)
y_pupil = pupil_radius * sin.(angles)

p1 = plot(x_outer, y_outer, fill=(0, :purple), legend=false, lw=4, grid=false, framestyle=:none, color=:black, axis_ratio=:equal)
plot!(x_inner, y_inner, fill=(0, :yellow))

p2 = plot(x_outer, y_outer, legend=false, lw=4, grid=false, framestyle=:none, color=:black, axis_ratio=:equal)
# for i = 1:40
#     if i == 19
#         plot!(p2, [0, x_outer[25*i]], [0, y_outer[25*i]], lw=4, color=:blue, arrow=true)
#     elseif i == 33
#         plot!(p2, [0, x_outer[25*i]], [0, y_outer[25*i]], lw=4, color=:lime, arrow=true)
#     elseif i == 40
#         plot!(p2, [0, x_outer[25*i]], [0, y_outer[25*i]], lw=4, color=:red, arrow=true)
#     else
#         plot!(p2, [0, x_outer[25*i]], [0, y_outer[25*i]], lw=1, color=:black)
#     end
# end
for i = 1:40
    if i == 19 || i == 33 || i == 40
        # Skip these iterations, where red, blue, and green lines would go
        continue
    else
        plot!(p2, [0, x_outer[25*i]], [0, y_outer[25*i]], lw=1, color=:black)
    end
end

p3 = plot(x_flat, y_flat, xticks=(x_tick_vals, x_tick_labels), lw=4, ylim=(-0.1, amplitude+0.4), yaxis=false, grid=false, legend=false, xtickfontsize=30, color=:black)
# plot!(p3, [x_flat[1], x_flat[1]], [-0.1, y_flat[1]], arrow=true, lw=4, linecolor=:red)
# plot!(p3, [x_flat[475], x_flat[475]], [-0.1, y_flat[475]], arrow=true, lw=4, linecolor=:blue)
# plot!(p3, [x_flat[826], x_flat[826]], [-0.1, y_flat[826]], arrow=true, lw=4, linecolor=:lime)

p4 = plot(x_fish_1, y_fish_1, legend = false, lw = 4, grid = false, framestyle = :none, color = :black, axis_ratio=:equal, fill =(0, :yellow))
p4 = plot!(x_fish_2, y_fish_2, legend = false, lw = 4, grid = false, framestyle = :none, color = :black, axis_ratio=:equal, fill =(0, :blue))
p4 = plot!(x_fish_3, y_fish_3, legend = false, lw = 4, grid = false, framestyle = :none, color = :black, axis_ratio=:equal, fill =(0, :yellow))
p4 = plot!([x_fish_3[1], x_fish_1[end]], [y_fish_3[1]+0, y_fish_1[end]-0], color = :blue, fill = (0, :yellow), lw = 4)
p4 = scatter!([x_fish_1[end]+0.01], [y_fish_1[end]-0.01], color = :black, markersize = 2)
p4 = scatter!([x_fish_1[end]-0.01], [y_fish_1[end]+0.01], color = :black, markersize = 2)
p4 = scatter!([x_fish_3[1]], [y_fish_3[1]], color = :black, markersize = 2)
p4 = plot!([0.08, 0.1], [0, 0.25], color = :yellow, lw = 4)
p4 = plot!([0.04, x_fish_3[128]], [0.15, y_fish_3[128]], color = :black, lw = 4)
p4 = plot!([0.022, x_fish_3[100]], [0.07, y_fish_3[100]], color = :black, lw = 4)
p4 = plot!([0.068, x_fish_1[10]], [0.25, y_fish_1[10]], color = :black, lw = 4)
plot!(-2.2 .+ x_eye, 1 .+ y_eye, fill=(0, :silver), color = :black, lw = 4)
plot!(-2.2 .+ x_pupil, 1 .+ y_pupil, fill = (0, :black), color = :black)

# Add back p5 and p6
p5 = plot(x_fish, y_fish, lw=4, grid=false, framestyle=:none, color=:black, legend=false, axis_ratio=:equal)
for i = 1:33
    if i == 7 || i == 14 || i == 31
        continue
    else
        plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw=1, color=:black)
    end
end

p6 = plot(θ_fish, fish_119, xticks=(x_tick_vals, x_tick_labels), ylim=(-0.5, maximum(fish_119) + 0.5), lw=4, yaxis=false, grid=false, legend=false, xtickfontsize=30, color=:black)
# plot!(p6, [θ_fish[98], θ_fish[98]], [-0.5, fish_119[98]], arrow=true, lw=4, linecolor=:red)
# plot!(p6, [θ_fish[196], θ_fish[196]], [-0.5, fish_119[196]], arrow=true, lw=4, linecolor=:blue)
# plot!(p6, [θ_fish[434], θ_fish[434]], [-0.5, fish_119[434]], arrow=true, lw=4, linecolor=:lime)

layout = @layout [grid(2, 3)]
combined_plot = plot(p1, p2, p3, p4, p5, p6, layout=layout, size=(1700, 1200))
# savefig(combined_plot, "flower_fish_combined.pdf")
#savefig("wontwork.svg")
savefig("herewego.tex")
# Out:
# "/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/herewego.tex"

# %%
# @show x_fish[14*7]
# @show y_fish[14*7]
p5 = plot(x_fish, y_fish, lw=4, grid=false, framestyle=:none, color=:black, legend=false, axis_ratio=:equal)
scatter!(p5, [x_fish[95]], [y_fish[95]])
scatter!(p5, [x_fish[325]], [y_fish[330]])

# if i == 7
#     plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 4, color = :red, arrow = true)
# elseif i == 14
#     plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 4, color = :blue, arrow = true)
# elseif i == 31
#     plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 4, color = :lime, arrow = true)

# %%
p4 = plot(x_fish_1, y_fish_1, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :yellow), dpi = 750)
p4 = plot!(x_fish_2, y_fish_2, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :blue))
p4 = plot!(x_fish_3, y_fish_3, legend = false, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, axis_ratio=:equal, fill =(0, :yellow))
p4 = plot!([x_fish_3[1], x_fish_1[end]], [y_fish_3[1]+0, y_fish_1[end]-0], color = :blue, fill = (0, :yellow), lw = 4)
p4 = scatter!([x_fish_1[end]+0.01], [y_fish_1[end]-0.01], color = :black, markersize = 2)
p4 = scatter!([x_fish_1[end]-0.01], [y_fish_1[end]+0.01], color = :black, markersize = 2)
p4 = scatter!([x_fish_3[1]], [y_fish_3[1]], color = :black, markersize = 2)
p4 = plot!([0.08, 0.1], [0, 0.25], color = :yellow, lw = 4)
p4 = plot!([0.04, x_fish_3[128]], [0.15, y_fish_3[128]], color = :black, lw = 4)
p4 = plot!([0.022, x_fish_3[100]], [0.07, y_fish_3[100]], color = :black, lw = 4)
p4 = plot!([0.068, x_fish_1[10]], [0.25, y_fish_1[10]], color = :black, lw = 4)
plot!(-2.2 .+ x_eye, 1 .+ y_eye, fill=(0, :silver), color = :black, lw = 4)
plot!(-2.2 .+ x_pupil, 1 .+ y_pupil, fill = (0, :black), color = :black)
p5 = plot(x_fish, y_fish, lw = 4, grid = false, framestyle = :none, axes = false, color = :black, legend = false, axis_ratio=:equal)
for i = 1:33
    if i == 7
        plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 4, color = :red, arrow = true)
    elseif i == 14
        plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 4, color = :blue, arrow = true)
    elseif i == 31
        plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 4, color = :lime, arrow = true)
    else
        plot!(p5, [0, x_fish[14*i]], [0.15, y_fish[14*i]], lw = 1, color = :black)
    end
end
p6 = plot(θ_fish, fish_119, xticks = (x_tick_vals, x_tick_labels), ylim = (-0.5, maximum(fish_119) + 0.5), lw = 4, yaxis = false, grid = false,
    legend = false, xtickfontsize=30, color = :black, bottom_margin = 11mm)
plot!(p6, [θ_fish[98], θ_fish[98]], [-0.5, fish_119[98]], arrow = true, lw = 4, linecolor = :red)
plot!(p6, [θ_fish[196], θ_fish[196]], [-0.5, fish_119[196]], arrow = true, lw = 4, linecolor = :blue)
plot!(p6, [θ_fish[434], θ_fish[434]], [-0.5, fish_119[434]], arrow = true, lw = 4, linecolor = :lime)

layout = @layout [grid(1, 3)]
combined_plot = plot(p4, p5, p6, layout = layout, size = (2500, 700), right_margin = 11mm)
savefig("just_fish.png")

# %%
using Plots
using Plots.Measures
using Combinatorics
using SpecialFunctions

# Define the domain of the plot
x = 1:0.1:50
x_2 = range(1, stop = 1, length = 50)

# Complexity functions
O_n(x) = x
O_logn(x) = log.(x)
O_nlogn(x) = x .* log.(x)
O_n2(x) = x.^2
O_2n(x) = 2.0.^x
O_n_fac(x) = gamma.(x .+ 1)

# Now define functions for colours
O_1(x) = x.^(0.9)
O_2(x) = x.^(1.15)
O_3(x) = x.^(1.5)
O_4(x) = range(1, stop = 200, length = 50)

# Create the plot
p = plot(xlims=(1, 50), ylims=(0, 200), xlabel="Elements", ylabel="Operations",
    grid = false, xticks = nothing, yticks = nothing, left_margin = 4mm, bottom_margin = -8mm, legend = false, xlabelfontsize = 13,
    ylabelfontsize = 13)

# Add fill_between areas for each complexity class
plot!(p, x, O_1(x), color = :lightgreen, fillrange = O_logn(x))
plot!(p, x, O_2(x), color = :yellow, fillrange = O_1(x))
plot!(p, x, O_3(x), color = :orange, fillrange = O_2(x))
x_fill = [0; x; 0]
y_fill = [0; O_3(x); O_3(x)[end]]
plot!(Shape(x_fill, y_fill), fillcolor=:red, linecolor = :red)
plot!(p, x, O_logn(x), fill=(0, :limegreen), label="O(log n), O(1)", color = :black)
plot!(p, x, O_n(x), label="O(n)", color = :black)
plot!(p, x, O_nlogn(x), label="O(n log n)", color = :black)
plot!(p, x, O_n2(x), label="O(n^2)", color = :black)
plot!(p, x, O_2n(x), label="O(2^n)", color = :black)
plot!(p, x, O_n_fac(x), color = :black)
annotate!(p, 45, 10, text(L"$O(\log n)$", 10))
annotate!(p, 45, 52, text(L"$O(n)$", 10))
annotate!(p, 37, 153, text(L"$O(n\log n)$", 10))
annotate!(p, 16, 175, text(L"$O(n^2)$", 10))
annotate!(p, 10, 175, text(L"$O(2^n)$", 10))
annotate!(p, 3, 175, text(L"$O(n!)$", 10))

p2 = plot(grid=false, axis=false, legend=false, xlims=(1, 50), ylims=(0, 1), top_margin=-1mm, bottom_margin = -7mm)
annotate!(p2, 6.5, 0.5, "Awful")
annotate!(p2, 15.8, 0.5, "Bad")
annotate!(p2, 25.1, 0.5, "Fair")
annotate!(p2, 34.35, 0.5, "Good")
annotate!(p2, 43.5, 0.5, "Terrific")
title!(p2, "Big-O Notation Machine Learning Complexity Chart", titlefontsize = 15)
x_coords_1 = [2.5, 10.5, 10.5, 2.5]
x_coords_2 = [11.75, 19.75, 19.75, 11.75]
x_coords_3 = [21, 29, 29, 21]
x_coords_4 = [30.25, 38.25, 38.25, 30.25]
x_coords_5 = [39.5, 47.5, 47.5, 39.5]
y_coords = [0.1, 0.1, 0.9, 0.9]
rec1 = Shape(x_coords_1, y_coords)
rec2 = Shape(x_coords_2, y_coords)
rec3 = Shape(x_coords_3, y_coords)
rec4 = Shape(x_coords_4, y_coords)
rec5 = Shape(x_coords_5, y_coords)
plot!(p2, rec1, linecolor=:red, fillcolor=:red)
plot!(p2, rec2, linecolor=:orange, fillcolor=:orange)
plot!(p2, rec3, linecolor=:yellow, fillcolor=:yellow)
plot!(p2, rec4, linecolor=:lightgreen, fillcolor=:lightgreen)
plot!(p2, rec5, linecolor=:limegreen, fillcolor=:limegreen)

# Overlay plot for the legend-like bar




# Combine the plots
layout = @layout([A{0.1h}; B{0.8h}])  # Adjusting the height ratios

combined_plot = plot(p2, p, layout=layout, link=:x, dpi = 700)

# Show the plot
display(combined_plot)

#2.5-10.5, 11.75-19.75, 21-29, 30.25-38.25, 39.5-47.5

savefig("big_o.png")

# %%
# OBC_train_accuracy = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_stoud_vary_chi_train_acc.csv", ',')
# OBC_test_accuracy = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_stoud_vary_chi_test_acc.csv", ',')
# OBC_train_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_stoud_vary_chi_train_loss.csv", ',')
# OBC_test_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/OBC_stoud_vary_chi_test_loss.csv", ',')
# PBC_train_accuracy = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_stoud_vary_chi_train_acc.csv", ',')
# PBC_test_accuracy = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_stoud_vary_chi_test_acc.csv", ',')
# PBC_train_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_stoud_vary_chi_train_loss.csv", ',')
# PBC_test_loss = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/PBC_stoud_vary_chi_test_loss.csv", ',')

# # plot(OBC_train_accuracy, lw = 4, label = "OBC Train")
# # plot!(OBC_test_accuracy, lw = 4, label = "OBC Test")
# # plot!(PBC_train_accuracy, lw = 4, label = "PBC Train")
# # plot!(PBC_test_accuracy, lw = 4, label = "PBC Test")
# # xlabel!("\$\\chi_{max}\$")
# # ylabel!("Accuracy")
# # title!("Comparison of OBC and PBC \n Algorithms Accuracy as a Function of \$\\chi_{max}\$")
# # savefig("OBC_PBC_accuracy_comparison_vary_chi_stoud_swedish_leaf.png")

# plot(OBC_train_loss, lw = 4, label = "OBC Loss")
# plot!(OBC_test_loss, lw = 4, label = "OBC Loss")
# plot!(PBC_train_loss, lw = 4, label = "PBC Loss")
# plot!(PBC_test_loss, lw = 4, label = "PBC Loss")
# xlabel!("\$\\chi_{max}\$")
# ylabel!("KLD Loss")
# title!("Comparison of OBC and PBC \n Algorithms KLD Loss as a Function of \$\\chi_{max}\$")
# savefig("OBC_PBC_loss_comparison_vary_chi_stoud_swedish_leaf.png")

PBC_both_train_accuracy = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/train_both_no_canonical_synthetic.csv", ',')
PBC_both_test_accuracy = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/test_both_no_canonical_synthetic.csv", ',')

findall(x->x==0, PBC_both_test_accuracy)

# %%
using Plots
using Random, Distributions

# Define the function to generate data with specific noise and autocorrelation characteristics
function generate_data(N, N_sine_train, N_sine_test, N_circle_train, N_circle_test, noise_factor, alpha_sine, alpha_circle)
    # Initialize matrices for training and testing data for sine and circle data sets
    sine_train = Matrix{Float64}(undef, N_sine_train, N)
    sine_test = Matrix{Float64}(undef, N_sine_test, N)
    circle_train = Matrix{Float64}(undef, N_circle_train, N)
    circle_test = Matrix{Float64}(undef, N_circle_test, N)
    train_labels = []
    test_labels = []

    x_min = 0
    x_max = 2π
    dx = (x_max - x_min) / N
    x = range(x_min, stop=x_max - dx, length=N)

    # Generate sine data with noise and specific autocorrelation
    for i = 1:N_sine_train
        y = (π / 2) * sin.(x)
        noise = rand(Normal(0, noise_factor), N)  # Gaussian noise
        y_noisy = y .+ noise
        y_noisy[end] = alpha_sine * y_noisy[1] + rand(Normal(0, noise_factor))  # Autocorrelation for sine
        sine_train[i, :] = y_noisy
        push!(train_labels, 0)
    end

    for i = 1:N_sine_test
        y = (π / 2) * sin.(x)
        noise = rand(Normal(0, noise_factor), N)  # Gaussian noise
        y_noisy = y .+ noise
        y_noisy[end] = alpha_sine * y_noisy[1] + rand(Normal(0, noise_factor))  # Autocorrelation for sine
        sine_test[i, :] = y_noisy
        push!(test_labels, 0)
    end

    # Generate circle data with noise and specific autocorrelation
    for i = 1:N_circle_train
        y = zeros(length(x))
        y[(x .>= 0) .& (x .< π)] .= sqrt.(π^2/4 .- (x[(x .>= 0) .& (x .< π)] .- π/2).^2)
        y[(x .>= π) .& (x .< 2π)] .= -sqrt.(π^2/4 .- (x[(x .>= π) .& (x .< 2π)] .- 3π/2).^2)
        noise = rand(Normal(0, noise_factor), N)  # Gaussian noise
        y_noisy = y .+ noise
        y_noisy[end] = alpha_circle * y_noisy[1] + rand(Normal(0, noise_factor))  # Opposite autocorrelation for circle
        circle_train[i, :] = y_noisy
        push!(train_labels, 1)
    end

    for i = 1:N_circle_test
        y = zeros(length(x))
        y[(x .>= 0) .& (x .< π)] .= sqrt.(π^2/4 .- (x[(x .>= 0) .& (x .< π)] .- π/2).^2)
        y[(x .>= π) .& (x .< 2π)] .= -sqrt.(π^2/4 .- (x[(x .>= π) .& (x .< 2π)] .- 3π/2).^2)
        noise = rand(Normal(0, noise_factor), N)  # Gaussian noise
        y_noisy = y .+ noise
        y_noisy[end] = alpha_circle * y_noisy[1] + rand(Normal(0, noise_factor))  # Opposite autocorrelation for circle
        circle_test[i, :] = y_noisy
        push!(test_labels, 1)
    end

    return x, sine_train, sine_test, circle_train, circle_test, train_labels, test_labels
end

x, sine_train, sine_test, circle_train, circle_test, train_labels, test_labels = generate_data(
    20, 20, 40, 20, 40, 0.7, 0.8, -0.8
)

X_train = vcat(sine_train, circle_train)
X_test = vcat(sine_test, circle_test)
X_train_copy = copy(X_train)
X_test_copy = copy(X_test)
@show X_train[1, :]
for i = 1:size(X_train_copy, 1)
    phase = rand() * 20
    shift = floor(Int, phase)
    shifted = circshift(X_train_copy[i, :], shift)
    X_train_copy[i, :] = shifted
end

for i = 1:size(X_test_copy, 1)
    phase = rand() * 20
    shift = floor(Int, phase)
    shifted = circshift(X_test_copy[i, :], shift)
    X_test_copy[i, :] = shifted
end

writedlm("sine_circle_train_10_40_80_1.csv", X_train, ",")
writedlm("sine_circle_test_10_40_80_1.csv", X_test, ",")
writedlm("sine_circle_train_10_40_80_1_shifted.csv", X_train_copy, ",")
writedlm("sine_circle_test_10_40_80_1_shifted.csv", X_test_copy, ",")
writedlm("sine_circle_train_10_40_80_1_labels.csv", train_labels, ",")
writedlm("sine_circle_test_10_40_80_1_labels.csv", test_labels, ",")

plot(vec(mean(sine_train, dims = 1)), lw = 4, label = "Mean Sine")
plot!(vec(mean(circle_train, dims = 1)), lw = 4, label = "Mean Semi-Circle")
xlabel!("x")
ylabel!("y")
title!("Sine vs Semi Circle Train Dataset Means")
# savefig("sine_semicircle_20_20_40_1.png")

# %%
# folder = "Plots"
# savefig(joinpath(folder, "distributions_500_20_1_0.1.pdf"))

folder = "datasets"
full_path = joinpath(folder, "guassian_curves_500_10_1_0.1_class_A.csv")
full_path_2 = joinpath(folder, "guassian_curves_500_10_1_0.1_class_A_labels.csv")
full_path_3 = joinpath(folder, "guassian_curves_500_10_1_0.1_class_B.csv")
full_path_4 = joinpath(folder, "guassian_curves_500_10_1_0.1_class_B_labels.csv")

writedlm(full_path, class_A, ',')
writedlm(full_path_2, class_A_label, ',')
writedlm(full_path_3, class_B, ',')
writedlm(full_path_4, class_B_label, ',')

# %%
using DelimitedFiles
train = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/train_obc_final.csv", ',')
test = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/test_obc_final.csv", ',')

function threshold_and_zero!(matrix::Matrix{Float64}, threshold::Float64)
    for i in 1:size(matrix, 1)
        for j in 1:size(matrix, 2)
            if matrix[i, j] < threshold
                matrix[i, j] = 0.0
            end
        end
    end
    return matrix
end
# Function to find indices of zero entries
function find_zero_indices(matrix)
    indices = []
    for i in 1:size(matrix, 1)
        for j in 1:size(matrix, 2)
            if matrix[i, j] == 0.0
                push!(indices, (i, j))
            end
        end
    end
    return indices
end

find_zero_indices(test)

# %%
#train[1, 8] = mean([0.884, 0.878])
#test[1, 8] = mean([0.882, 0.876])
#train[1, 13] = mean([0.89, 0.892, 0.884])
#test[1, 13] = mean([0.884, 0.884, 0.882])

# %%
using Random, Distributions, Statistics

function generate_periodic_time_series(n, length, corr_class, amplitude, frequency)
    series = zeros(n, length)
    #t = range(0, stop=2pi, length=length) # Time variable for the sine function
    x_min = 0
    x_max = 2π
    dx = (x_max - x_min) / (n_points)
    t = range(x_min, stop=x_max - dx, length=length)
    base_pattern = amplitude * sin.(frequency * t) # Base periodic pattern

    for i in 1:n
        # Generate a periodic time series with Gaussian noise
        ts = base_pattern .+ randn(length) * 0.5  # Adjust 0.5 to control noise level
        
        # Modify the last point to ensure specific correlation with the first point
        ts[end] = corr_class * ts[1] + sqrt(1 - corr_class^2) * randn() + base_pattern[end]
        
        series[i, :] = ts
    end
    return series
end

# Parameters
num_samples = 100  # Number of time series samples
ts_length = 20     # Length of each time series
amplitude = 1      # Amplitude of the sine wave
frequency = 1 # Frequency of the sine wave
correlation_class1 = 0.99  # High correlation for Class 1
correlation_class2 = -0.99 # Negative correlation for Class 2

# Generate the time series data for both classes
class1_data = generate_periodic_time_series(num_samples, ts_length, correlation_class1, amplitude, frequency)
class2_data = generate_periodic_time_series(num_samples, ts_length, correlation_class2, amplitude, frequency)

# Function to calculate correlation between first and last point
correlation_first_last = (data) -> cor(data[:, 1], data[:, end])

# # Display the correlations for verification
# println("Average correlation in Class 1: ", mean(correlation_first_last(class1_data)))
# println("Average correlation in Class 2: ", mean(correlation_first_last(class2_data)))

plot(vec(mean(class1_data, dims=1)), lw = 4)
plot!(vec(mean(class2_data, dims = 1)), lw = 4)

# plot(class1_data[1, :])
# plot!(class2_data[1, :])

writedlm("sine_class_A.csv", class1_data, ",")
writedlm("sine_class_B.csv", class2_data, ",")

# %%
scatter_plot_classes(class_A, class_B, alpha, y_int, noise_strength)

# %%
# train_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/Data/train_fourier_chi_2_eta_0.05_matrix.csv", ',')
# test_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/Data/test_fourier_chi_2_eta_0.05_matrix.csv", ',')
# train_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/Data/train_fourier_chi_2_eta_0.05_sweeps_40_PBC_both.csv", ',')
# test_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/LogLoss/Data/test_fourier_chi_2_eta_0.05_sweeps_40_PBC_both.csv", ',')

train_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/train_obc_final.csv", ',')
test_OBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/test_obc_final.csv", ',')
train_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/train_random_new_seeds_guassian_v7.csv", ',')
test_PBC = readdlm("/Users/angusrutherford/Desktop/Honours/Project/Code/QuantumInspiredML/test_random_new_seeds_guassian_v7.csv", ',')

mean_train_OBC = mean(train_OBC, dims = 1)
mean_train_OBC = vec(mean_train_OBC)
pushfirst!(mean_train_OBC, mean_train_OBC[end])

mean_test_OBC = mean(test_OBC, dims = 1)
mean_test_OBC = vec(mean_test_OBC)
pushfirst!(mean_test_OBC, mean_test_OBC[end])

mean_train_PBC = mean(train_PBC, dims = 1)
mean_train_PBC = vec(mean_train_PBC)
pushfirst!(mean_train_PBC, mean_train_PBC[end])

mean_test_PBC = mean(test_PBC, dims = 1)
mean_test_PBC = vec(mean_test_PBC)
pushfirst!(mean_test_PBC, mean_test_PBC[end])

std_train_OBC = std(train_OBC, dims = 1)
std_train_OBC = vec(std_train_OBC)
pushfirst!(std_train_OBC, std_train_OBC[end])

std_test_OBC = std(test_OBC, dims = 1)
std_test_OBC = vec(std_test_OBC)
pushfirst!(std_test_OBC, std_test_OBC[end])

std_train_PBC = std(train_PBC, dims = 1)
std_train_PBC = vec(std_train_PBC)
pushfirst!(std_train_PBC, std_train_PBC[end])

std_test_PBC = std(test_PBC, dims = 1)
std_test_PBC = vec(std_test_PBC)
pushfirst!(std_test_PBC, std_test_PBC[end])

x = range(-pi, stop = pi, length = 21)
x_tick_vals = range(-pi, stop = pi, length = 5)
x_tick_labels = ["-π", "-π/2", "0", "π/2", "π"]

plot(x, mean_test_OBC, ribbon = std_test_OBC, xticks = (x_tick_vals, x_tick_labels), linewidth = 4, label = "Mean Testing Accuracy (OBC) ± 1 SD", legend = :right)
#plot!(x, mean_test_OBC, ribbon = std_test_OBC, linewidth = 4, label = "Mean Testing Accuracy (OBC) ± 1 SD")
plot!(x, mean_test_PBC, ribbon = std_test_PBC, linewidth = 4, label = "Mean Testing Accuracy (PBC) ± 1 SD")
# plot!(x, mean_test_PBC, ribbon = std_test_PBC, linewidth = 4, label = "Mean Testing Accuracy (PBC) ± 1 SD")
xlabel!("Phase (radians)")
ylabel!("Accuracy")
#title!("Training and Testing Accuracies for PBC Random Walk on Synthetic \n Dataset, \$\\chi_{max}=2\$, \$\\eta=0.05\$, Fourier Encoding, 25 MPS Initialisations \n Using Differing Random Walk Seeds Version Seven", titlefontsize=11)
title!("Comparison of Testing Accuracies for OBC and PBC \n Random Walk in Synthetic  Dataset \$\\chi_{max}=2\$, \$\\eta=0.05\$, \n Fourier Encoding, 25 MPS Initialisations", titlefontsize=11)
#savefig("comparison_train_and_test_OBC_PBC_fourier_chi_2_eta_0.05.pdf")
#savefig("synthetic_test_train_new_PBC_random_walk_new_seeds_v6.png")
savefig("synthetic_comparison_test_OBC_and_PBC_random_walk_final.png")

# %%
plot(x, mean_train_PBC, ribbon = std_train_PBC, xticks = (x_tick_vals, x_tick_labels), linewidth = 4, label = "Mean Training Accuracy ± 1 SD")
plot!(x, mean_test_PBC, ribbon = std_test_PBC, xticks = (x_tick_vals, x_tick_labels), linewidth = 4, label = "Mean Testing Accuracy ± 1 SD")
xlabel!("Phase (radians)")
ylabel!("Accuracy")
title!("PBC (both) MPS Classifier, \$\\chi_{max}=2\$, \$\\eta=0.05\$, 40 Sweeps, \n Fourier Encoding, Averaged Over 25 MPS Initialisations", titlefontsize=13)
savefig("pbc_both_synthetic_fourier_chi_2_eta_0.05_20_initialisations.pdf")

# %%
zero_obc_train = train_OBC[:, 10]
zero_obc_test = test_OBC[:, 10]

zero_pbc_train = train_PBC[:, 10]
zero_pbc_test = test_PBC[:, 10]

seeds = 1:20
plot(seeds, zero_obc_train, linewidth = 4, label = "Training Accuracy (OBC)", legend=:left)
plot!(seeds, zero_obc_test, linewidth = 4, label = "Testing Accuracy (OBC)")
plot!(seeds, zero_pbc_train, linewidth = 4, label = "Training Accuracy (PBC)")
plot!(seeds, zero_pbc_test, linewidth = 4, label = "Testing Accuracy (PBC)")
xlabel!("Seeds")
ylabel!("Accuracy")
title!("Zero Phase Training and Testing Accuracies as a \n Function of Seeds for OBC and PBC (both) Algorithms", titlefontsize=13)
savefig("zero_phase_training_testing_seeds_OBC_PBC.pdf")

# %%
using ITensors
using Random
using Distributions
using Folds
using StatsBase
using Plots
using MLBase
using PrettyTables
using StatisticalMeasures


function contractMPS(W::MPS, PS::PState)
        N_sites = length(W)
        res = 1
        for i=1:N_sites
            res *= W[i] * conj(PS.pstate[i])
        end

        return res 

end



function MSE_loss_acc_iter(W::MPS, PS::PState)
    """For a given sample, compute the Quadratic Cost and whether or not
    the corresponding prediction (using argmax on deicision func. output) is
    correctly classfified"""
    label = PS.label # ground truth label
    pos, label_idx = find_label(W)
    y = onehot(label_idx => label+1)


    yhat = contractMPS(W, PS)
    
    diff_sq = abs2.(array(yhat - y))
    sum_of_sq_diff = real(sum(diff_sq))

    loss = 0.5 * sum_of_sq_diff

    # now get the predicted label
    correct = 0
    
    if (argmax(abs.(vector(yhat))) - 1) == PS.label
        correct = 1
    end

    return [loss, correct]

end

function MSE_loss_acc(W::MPS, PSs::TimeseriesIterable)
    """Compute the MSE loss and accuracy for an entire dataset"""
    loss, acc = Folds.reduce(+, MSE_loss_acc_iter(W, PS) for PS in PSs)
    loss /= length(PSs)
    acc /= length(PSs)

    return loss, acc 

end

function MSE_loss_acc_conf_iter(W::MPS, PS::PState)
    """For a given sample, compute the Quadratic Cost and whether or not
    the corresponding prediction (using argmax on deicision func. output) is
    correctly classfified"""
    label = PS.label # ground truth label
    pos, label_idx = find_label(W)
    y = onehot(label_idx => label+1)


    yhat = contractMPS(W, PS)
    
    diff_sq = abs2.(array(yhat - y))
    sum_of_sq_diff = real(sum(diff_sq))

    loss = 0.5 * sum_of_sq_diff

    # now get the predicted label
    correct = 0
    pred = argmax(abs.(vector(yhat))) - 1
    if pred == label
        correct = 1
    end

    conf = zeros(Int64,2,2)
    conf[label+1, pred+1] = 1

    return [loss, correct, conf]

end

function MSE_loss_acc_conf(W::MPS, PSs::TimeseriesIterable)
    loss, acc, conf = Folds.reduce(+, MSE_loss_acc_conf_iter(W, PS) for PS in PSs)
    loss /= length(PSs)
    acc /= length(PSs)

    return loss, acc, conf

end

function get_predictions(Ws::Vector{MPS}, pss::TimeseriesIterable)
    # mps0 overlaps with ORIGINAL class 0 and mps1 overlaps with ORIGINAL class 1
    @assert all(length(Ws[1]) .== length.(Ws)) "MPS lengths do not match!"

    preds = Vector{Int64}(undef, length(pss))
    all_overlaps = Vector{Vector{Float64}}(undef, length(pss))
    for i in eachindex(pss)
        psc = conj(pss[i].pstate)
        overlaps = [ITensor(1) for _ in Ws]
        for (wi,w) in enumerate(Ws), j in eachindex(Ws[1])
            overlaps[wi] *= w[j] * psc[j]
        end
        overlaps = abs.(first.(overlaps))
        pred = argmax(overlaps) - 1
        preds[i] = pred

        all_overlaps[i] = overlaps
    end

    # return overlaps as well for inspection
    return preds, all_overlaps
        
end


function overlap_confmat(mps0::MPS, mps1::MPS, pstates::TimeseriesIterable; plot=false)
    """(2 CLASSES ONLY) Something like a confusion matrix but for median overlaps.
    Here, mps0 is the mps which overlaps with class 0 and mps1 overlaps w/ class 1"""
    gt_class_0_idxs = [ps.label .== 0 for ps in pstates]
    gt_class_1_idxs = [ps.label .== 1 for ps in pstates]
    # gt class 0, overlap with mps0, we will call this a true negative
    gt_0_mps_0 = [get_overlap(mps0, ps) for ps in pstates[gt_class_0_idxs]]
    # gt class 0, overlaps with mps1, false positive
    gt_0_mps_1 = [get_overlap(mps1, ps) for ps in pstates[gt_class_0_idxs]]
    # gt class 1, overlap with mps0, false negative
    gt_1_mps_0 = [get_overlap(mps0, ps) for ps in pstates[gt_class_1_idxs]]
    # gt class 1, overlaps with mps1, true positive
    gt_1_mps_1 = [get_overlap(mps1, ps) for ps in pstates[gt_class_1_idxs]]

    # get medians
    gt_0_mps_0_median = median(gt_0_mps_0)
    gt_0_mps_1_median = median(gt_0_mps_1)
    gt_1_mps_0_median = median(gt_1_mps_0)
    gt_1_mps_1_median = median(gt_1_mps_1)
    confmat = [gt_0_mps_0_median gt_0_mps_1_median; gt_1_mps_0_median gt_1_mps_1_median]

    # dictionary of stats
    #⟨ps|mps⟩
    stats = Dict(
        "Min/Max ⟨0|0⟩" => (minimum(gt_0_mps_0), maximum(gt_0_mps_0)),
        "Min/Max ⟨1|0⟩" => (minimum(gt_1_mps_0), maximum(gt_1_mps_0)),
        "Min/Max ⟨0|1⟩" => (minimum(gt_0_mps_1), maximum(gt_0_mps_1)),
        "Min/Max ⟨1|1⟩" => (minimum(gt_1_mps_1), maximum(gt_1_mps_1)),
        "MPS States Overlap ⟨1|0⟩" => abs(inner(mps0, mps1))
    )

    if plot
        reversed_confmat = reverse(confmat, dims=1)
        hmap = heatmap(reversed_confmat,
        color=:Blues,
        xticks=(1:size(confmat,2), ["Predicted 0", "Predicted 1"]),
        yticks=(1:size(confmat,1), ["Actual 1", "Actual 0"]),
        xlabel="Predicted class",
        ylabel="Actual class",
        title="Median Overlap Confusion Matrix")

        for (i, row) in enumerate(eachrow(reversed_confmat))
            for (j, value) in enumerate(row)
                
                annotate!(j, i, text(string(value), :center, 10))
            end
        end

        display(hmap)

    end

    return confmat, stats

end

function plot_conf_mat(confmat::Matrix)
    reversed_confmat = reverse(confmat, dims=1)
    hmap = heatmap(reversed_confmat,
        color=:Blues,
        xticks=(1:size(confmat,2), ["Predicted $n" for n in 0:(size(confmat,2) - 1)]),
        yticks=(1:size(confmat,1), reverse(["Actual n" for n in 0:(size(confmat,1) - 1)]) ),
        xlabel="Predicted class",
        ylabel="Actual class",
        title="Confusion Matrix")
        
    for (i, row) in enumerate(eachrow(reversed_confmat))
        for (j, value) in enumerate(row)
            
            annotate!(j, i, text(string(value), :center, 10))
        end
    end

    display(hmap)
end





function get_training_summary(mps::MPS, training_pss::TimeseriesIterable, testing_pss::TimeseriesIterable; print_stats=false,io::IO=stdin)
    # get final traing acc, final training loss

    Ws, l_ind = expand_label_index(mps)
    nclasses = length(Ws)

    preds_training, overlaps = get_predictions(Ws, training_pss)
    true_training = [x.label for x in training_pss] # get ground truths
    acc_training = sum(true_training .== preds_training)/length(training_pss)
    

    # get final testing acc
    preds_testing, overlaps = get_predictions(Ws, testing_pss)
    true_testing =  [x.label for x in testing_pss] # get ground truths

    # get overlap between mps classes
    overlapmat = Matrix{Float64}(undef, nclasses, nclasses)
    for i in eachindex(Ws), j in eachindex(Ws)
        overlapmat[i,j] = abs(dot(Ws[i], Ws[j])) # ITensor dot product conjugates the first argument
    end

    
    confmat = confusmat(nclasses, (true_testing .+ 1), (preds_testing .+ 1)) # need to offset labels becuase function expects labels to start at 1


    # NOTE CONFMAT IS R(i, j) == countnz((gt .== i) & (pred .== j)). So rows (i) are groudn truth and columns (j) are preds
    # tables 
    pretty_table(io,overlapmat;
                    title="Overlap Matrix",
                    title_alignment=:c,
                    title_same_width_as_table=true,
                    header = ["|ψ$n⟩" for n in 0:(nclasses-1)],
                    row_labels = ["⟨ψ$n|" for n in 0:(nclasses-1)],
                    alignment=:c,
                    body_hlines=Vector(1:nclasses),
                    highlighters = Highlighter(f      = (data, i, j) -> (i == j),
                    crayon = crayon"bold" ),
                    formatters = ft_printf("%5.3e"))

    pretty_table(io,confmat;
    title="Confusion Matrix",
    title_alignment=:c,
    title_same_width_as_table=true,
    header = ["Pred. |$n⟩" for n in 0:(nclasses-1)],
    row_labels = ["True |$n⟩" for n in 0:(nclasses-1)],
    body_hlines=Vector(1:nclasses),
    highlighters = Highlighter(f = (data, i, j) -> (i == j), crayon = crayon"bold green" ))


    # TP, TN, FP, FN FOR TEST SET 
    acc_testing = sum(true_testing .== preds_testing)/length(testing_pss)
    r = roc(true_testing, preds_testing)
    prec = precision(r)
    rec = recall(r)
    f1 = f1score(r)
    specificity = true_negative(r) / (true_negative(r) + false_positive(r))
    sensitivity = true_positive(r) / (true_positive(r) + false_negative(r))
    # balanced acc is arithmetic mean of sensitivy and specificity
    acc_balanced_testing = (sensitivity + specificity) / 2

    stats = Dict(
        :train_acc => acc_training,
        :test_acc => acc_testing,
        :test_balanced_acc => acc_balanced_testing,
        :precision => prec,
        :recall => rec,
        :specificity => specificity,
        :f1_score => f1,
        :confmat => confmat
    )

    if print_stats
        statsp = Dict(String(key)=>[stats[key]] for key in filter((s)->s!=:confmat,keys(stats)))
        pretty_table(io,statsp)
        # println("Testing Accuracy: $acc_testing")
        # println("Training Accuracy: $acc_training")
        # println("Precision: $prec")
        # println("Recall: $rec")
        # println("F1 Score: $f1")
        # println("Specificity: $specificity")
        # println("Sensitivity: $sensitivity")
        # println("Balanced Accuracy: $acc_balanced_testing")
    end
    
    return stats

end

function sweep_summary(info;io::IO=stdin)
    """Print a pretty summary of what happened in every sweep"""
    nsweeps = length(info["time_taken"]) - 2
    row_labels = ["Accuracy", "Test KL Div.", "Train KL Div.", "Test MSE", "Time taken"]
    header = vcat(["Initial"],["After Sweep $n" for n in 1:(nsweeps)], ["After Norm"], "Mean")

    data = Matrix{Float64}(undef, length(row_labels), nsweeps+3)

    for (i, key) in enumerate(["test_acc", "test_KL_div", "train_KL_div", "test_loss", "time_taken"])
        data[i,:] = vcat(info[key], [mean(info[key][2:end-1])])
    end

    h1 = Highlighter((data, i, j) -> j < length(header) && data[i, j] == maximum(data[i,1:(end-1)]),
                        bold       = true,
                        foreground = :red )

    h2 = Highlighter((data, i, j) -> j < length(header) && data[i, j] == minimum(data[i,1:(end-1)]),
    bold       = true,
    foreground = :blue )

    pretty_table(io,data;
    row_label_column_title = "",
    header = header,
    row_labels = row_labels,
    body_hlines = Vector(1:length(row_labels)),
    highlighters = (h1,h2),
    alignment=:c)
    #formatters = ft_printf("%.3e"))

end

function print_opts(opts::Options;io::IO=stdin)
    optsD = Dict(String(key)=>[getfield(opts, key)] for key in  fieldnames(Options))
    return pretty_table(io, optsD)
end


function KL_div(W::MPS, test_states::TimeseriesIterable)
    """Computes KL divergence of TS on MPS"""
    Ws, l_ind = expand_label_index(W)

    KLdiv = 0

    for x in test_states, l in eachval(l_ind)
        if x.label == l - 1
            qlx = abs2(first(contractMPS(Ws[l],x)))
            #qlx = l == 0 ? abs2(dot(x.pstate,W0)) : abs2(dot(x.pstate, W1))
            KLdiv +=  -log(qlx) # plx is 1
        end
    end
    return KLdiv / length(test_states)
end

function KL_div_old(W::MPS, test_states::TimeseriesIterable)
    """Computes KL divergence of TS on MPS, only works for a 2 category label index"""
    W0, W1, l_ind = expand_label_index(W)

    KLdiv = 0

    for x in test_states, l in 0:1
        if x.label == l
            qlx = l == 0 ? abs2(dot(x.pstate,W0)) : abs2(dot(x.pstate, W1))
            KLdiv +=  -log(qlx) # plx is 1
        end
    end
    return KLdiv / length(test_states)
end

function test_dot(W::MPS, test_states::TimeseriesIterable)
    Ws, l_ind = expand_label_index(W)

    outcomes = []
    for (i,ps) in enumerate(test_states)
        inns = [inner(ps.pstate, mps) for mps in Ws]
        cons = Vector(contractMPS(W, ps))

        if !all(isapprox.(inns,cons))
            push!(outcomes,i)
        end
    end
    return outcomes
end
